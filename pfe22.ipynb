# %%
import pandas as pd
import csv
import numpy as np 

df = pd.read_csv(r'C:\Users\sofi\Downloads\wetransfer-3ab4ca\2018.csv',sep=';', encoding = 'ISO-8859-1',
                     names=['ID_ORDER', 'DATE-ADD','TIME-ADD','LOCATION','ID_CUSTOMER','LAST_NAME','FIRST_NAME','YX_LIBELLE','BIRTH_YEAR','TELEX','EMAIL','ADRESS','POSTAL_CODE','CITY','ITEM_CODE','CC_LIBELLE','CC_LIBELLE_1','DESIGNATION','PVTTC','QTEFACT','PUTTCNET','MLR_REMISE','GTR_LIBELLE'],
                     dtype={'ID_ORDER':int,'DATE-ADD':object,'TIME-ADD':object,'LOCATION':int,'ID_CUSTOMER':object,'LAST_NAME':object,'FIRST_NAME':object,'YX_LIBELLE':object,'BIRTH_YEAR':object,'TELEX':object,'EMAIL':object,'ADRESS':object,'POSTAL_CODE':object,'CITY':object,'ITEM_CODE':object,'CC_LIBELLE':object,'CC_LIBELLE_1':object})

df
# Out:
# C:\Users\sofi\Anacondaa\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (18,19,20) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#         ID_ORDER                 DATE-ADD                 TIME-ADD  LOCATION  \
# 0       66032518  2018-01-01 00:00:00.000  2018-01-01 12:06:50.000        66
# 1       80143573  2018-01-01 00:00:00.000  2018-01-01 16:03:37.000         8
# 2       80143576  2018-01-01 00:00:00.000  2018-01-01 17:38:26.000         8
# 3       80143572  2018-01-01 00:00:00.000  2018-01-01 14:52:08.000         8
# 4       80143574  2018-01-01 00:00:00.000  2018-01-01 16:56:04.000         8
# ...          ...                      ...                      ...       ...
# 536843  24168599  2018-12-31 00:00:00.000  2018-12-31 13:40:18.000        24
# 536844  24168598  2018-12-31 00:00:00.000  2018-12-31 13:39:30.000        24
# 536845  24168602  2018-12-31 00:00:00.000  2018-12-31 14:40:15.000        24
# 536846  14142423  2018-12-31 00:00:00.000  2018-12-31 11:04:33.000        14
# 536847  14142426  2018-12-31 00:00:00.000  2018-12-31 11:16:19.000        14
#
#        ID_CUSTOMER          LAST_NAME FIRST_NAME  YX_LIBELLE BIRTH_YEAR  \
# 0         SC000004  CLIENT de PASSAGE        NaN    PASSAGER          0
# 1         SC000004  CLIENT de PASSAGE        NaN    PASSAGER          0
# 2         SC000004  CLIENT de PASSAGE        NaN    PASSAGER          0
# 3         SC000004  CLIENT de PASSAGE        NaN    PASSAGER          0
# 4         SC000004  CLIENT de PASSAGE        NaN    PASSAGER          0
# ...            ...                ...        ...         ...        ...
# 536843    S2020706         BEN HAMIDA      Sonia         NaN       1974
# 536844    S2020706         BEN HAMIDA      Sonia         NaN       1974
# 536845   BC0240557            ZEDDINI       Wael  PARTENAIRE       1900
# 536846   BC0080855             BRAIKI     Mariem  PARTENAIRE       1900
# 536847    SC000004  CLIENT de PASSAGE        NaN    PASSAGER          0
#
#            TELEX  ...      CITY           ITEM_CODE     CC_LIBELLE  \
# 0            NaN  ...     TUNIS    6BL00F051401F18H    SASIO FEMME
# 1            NaN  ...     TUNIS       4PUPH45NRS18H    BLUE ISLAND
# 2            NaN  ...     TUNIS         6CR04NRS18H    SASIO FEMME
# 3            NaN  ...     TUNIS    22BL00FR0501518H  REQUEST FEMME
# 4            NaN  ...     TUNIS    6SW00F071556F18H    SASIO FEMME
# ...          ...  ...       ...                 ...            ...
# 536843  98691207  ...  ZARZOUNA  17CHC00H10830DC19H    ISLAND CLUB
# 536844  98691207  ...  ZARZOUNA   17PA00H111360C19H    ISLAND CLUB
# 536845  21882114  ...       NaN         4PU18CND18H    BLUE ISLAND
# 536846  22494208  ...       NaN    27PA00BS1105219H     BLEU & SON
# 536847       NaN  ...     TUNIS    4PA00H111351F19H    BLUE ISLAND
#
#        CC_LIBELLE_1          DESIGNATION     PVTTC QTEFACT PUTTCNET  \
# 0            BLOUSE                 ROUX      79.9      -1   -39.95
# 1              PULL                 BLEU      79.9       1      NaN
# 2          CARDIGAN     MARINE/ROSE PALE      84.9       1      NaN
# 3            BLOUSE  MARINE/ROSE VIOLINE      49.9       1      NaN
# 4       SWEAT SHIRT           ROSE CLAIR      59.9       1      NaN
# ...             ...                  ...       ...     ...      ...
# 536843      CHEMISE         BEIGE/MARRON  109.0000       1      NaN
# 536844     PANTALON               MARRON  129.0000       1      NaN
# 536845         PULL            GRIS PALE   89.9000       1      NaN
# 536846     PANTALON                CAMEL   59.9000      -1    -59.8
# 536847     PANTALON                BEIGE  109.0000      -1    -98.9
#
#        MLR_REMISE GTR_LIBELLE
# 0         50.0000         NaN
# 1             NaN         NaN
# 2             NaN         NaN
# 3             NaN         NaN
# 4             NaN         NaN
# ...           ...         ...
# 536843        NaN         NaN
# 536844        NaN         NaN
# 536845        NaN         NaN
# 536846     0.1669         NaN
# 536847     9.2661         NaN
#
# [536848 rows x 23 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 536848 entries, 0 to 536847
# Data columns (total 23 columns):
# ID_ORDER        536848 non-null int32
# DATE-ADD        536848 non-null object
# TIME-ADD        536848 non-null object
# LOCATION        536848 non-null int32
# ID_CUSTOMER     536848 non-null object
# LAST_NAME       536848 non-null object
# FIRST_NAME      271624 non-null object
# YX_LIBELLE      426416 non-null object
# BIRTH_YEAR      536833 non-null object
# TELEX           267784 non-null object
# EMAIL           134450 non-null object
# ADRESS          177862 non-null object
# POSTAL_CODE     439634 non-null object
# CITY            439129 non-null object
# ITEM_CODE       536847 non-null object
# CC_LIBELLE      536387 non-null object
# CC_LIBELLE_1    536387 non-null object
# DESIGNATION     536387 non-null object
# PVTTC           536848 non-null object
# QTEFACT         536848 non-null object
# PUTTCNET        445275 non-null object
# MLR_REMISE      445214 non-null float64
# GTR_LIBELLE     439960 non-null object
# dtypes: float64(1), int32(2), object(20)
# memory usage: 90.1+ MB

# %%
#convert DataFrame column to date-time:'GP_DATEPIECE'
df['DATE-ADD'] = pd.to_datetime(df['DATE-ADD'], format = '%Y-%m-%d')
df['DATE-ADD']= pd.to_datetime(df['DATE-ADD'], errors='ignore')
df.head()
# Out:
#    ID_ORDER   DATE-ADD                 TIME-ADD  LOCATION ID_CUSTOMER  \
# 0  66032518 2018-01-01  2018-01-01 12:06:50.000        66    SC000004
# 1  80143573 2018-01-01  2018-01-01 16:03:37.000         8    SC000004
# 2  80143576 2018-01-01  2018-01-01 17:38:26.000         8    SC000004
# 3  80143572 2018-01-01  2018-01-01 14:52:08.000         8    SC000004
# 4  80143574 2018-01-01  2018-01-01 16:56:04.000         8    SC000004
#
#            LAST_NAME FIRST_NAME YX_LIBELLE BIRTH_YEAR TELEX  ...   CITY  \
# 0  CLIENT de PASSAGE        NaN   PASSAGER          0   NaN  ...  TUNIS
# 1  CLIENT de PASSAGE        NaN   PASSAGER          0   NaN  ...  TUNIS
# 2  CLIENT de PASSAGE        NaN   PASSAGER          0   NaN  ...  TUNIS
# 3  CLIENT de PASSAGE        NaN   PASSAGER          0   NaN  ...  TUNIS
# 4  CLIENT de PASSAGE        NaN   PASSAGER          0   NaN  ...  TUNIS
#
#           ITEM_CODE     CC_LIBELLE CC_LIBELLE_1          DESIGNATION PVTTC  \
# 0  6BL00F051401F18H    SASIO FEMME       BLOUSE                 ROUX  79.9
# 1     4PUPH45NRS18H    BLUE ISLAND         PULL                 BLEU  79.9
# 2       6CR04NRS18H    SASIO FEMME     CARDIGAN     MARINE/ROSE PALE  84.9
# 3  22BL00FR0501518H  REQUEST FEMME       BLOUSE  MARINE/ROSE VIOLINE  49.9
# 4  6SW00F071556F18H    SASIO FEMME  SWEAT SHIRT           ROSE CLAIR  59.9
#
#   QTEFACT PUTTCNET MLR_REMISE GTR_LIBELLE
# 0      -1   -39.95       50.0         NaN
# 1       1      NaN        NaN         NaN
# 2       1      NaN        NaN         NaN
# 3       1      NaN        NaN         NaN
# 4       1      NaN        NaN         NaN
#
# [5 rows x 23 columns]

# %%
df['TIME-ADD'] = pd.to_datetime(df['TIME-ADD'])

df
# Out:
#         ID_ORDER   DATE-ADD            TIME-ADD  LOCATION ID_CUSTOMER  \
# 0       66032518 2018-01-01 2018-01-01 12:06:50        66    SC000004
# 1       80143573 2018-01-01 2018-01-01 16:03:37         8    SC000004
# 2       80143576 2018-01-01 2018-01-01 17:38:26         8    SC000004
# 3       80143572 2018-01-01 2018-01-01 14:52:08         8    SC000004
# 4       80143574 2018-01-01 2018-01-01 16:56:04         8    SC000004
# ...          ...        ...                 ...       ...         ...
# 536843  24168599 2018-12-31 2018-12-31 13:40:18        24    S2020706
# 536844  24168598 2018-12-31 2018-12-31 13:39:30        24    S2020706
# 536845  24168602 2018-12-31 2018-12-31 14:40:15        24   BC0240557
# 536846  14142423 2018-12-31 2018-12-31 11:04:33        14   BC0080855
# 536847  14142426 2018-12-31 2018-12-31 11:16:19        14    SC000004
#
#                 LAST_NAME FIRST_NAME  YX_LIBELLE BIRTH_YEAR     TELEX  ...  \
# 0       CLIENT de PASSAGE        NaN    PASSAGER          0       NaN  ...
# 1       CLIENT de PASSAGE        NaN    PASSAGER          0       NaN  ...
# 2       CLIENT de PASSAGE        NaN    PASSAGER          0       NaN  ...
# 3       CLIENT de PASSAGE        NaN    PASSAGER          0       NaN  ...
# 4       CLIENT de PASSAGE        NaN    PASSAGER          0       NaN  ...
# ...                   ...        ...         ...        ...       ...  ...
# 536843         BEN HAMIDA      Sonia         NaN       1974  98691207  ...
# 536844         BEN HAMIDA      Sonia         NaN       1974  98691207  ...
# 536845            ZEDDINI       Wael  PARTENAIRE       1900  21882114  ...
# 536846             BRAIKI     Mariem  PARTENAIRE       1900  22494208  ...
# 536847  CLIENT de PASSAGE        NaN    PASSAGER          0       NaN  ...
#
#             CITY           ITEM_CODE     CC_LIBELLE CC_LIBELLE_1  \
# 0          TUNIS    6BL00F051401F18H    SASIO FEMME       BLOUSE
# 1          TUNIS       4PUPH45NRS18H    BLUE ISLAND         PULL
# 2          TUNIS         6CR04NRS18H    SASIO FEMME     CARDIGAN
# 3          TUNIS    22BL00FR0501518H  REQUEST FEMME       BLOUSE
# 4          TUNIS    6SW00F071556F18H    SASIO FEMME  SWEAT SHIRT
# ...          ...                 ...            ...          ...
# 536843  ZARZOUNA  17CHC00H10830DC19H    ISLAND CLUB      CHEMISE
# 536844  ZARZOUNA   17PA00H111360C19H    ISLAND CLUB     PANTALON
# 536845       NaN         4PU18CND18H    BLUE ISLAND         PULL
# 536846       NaN    27PA00BS1105219H     BLEU & SON     PANTALON
# 536847     TUNIS    4PA00H111351F19H    BLUE ISLAND     PANTALON
#
#                 DESIGNATION     PVTTC QTEFACT PUTTCNET MLR_REMISE GTR_LIBELLE
# 0                      ROUX      79.9      -1   -39.95    50.0000         NaN
# 1                      BLEU      79.9       1      NaN        NaN         NaN
# 2          MARINE/ROSE PALE      84.9       1      NaN        NaN         NaN
# 3       MARINE/ROSE VIOLINE      49.9       1      NaN        NaN         NaN
# 4                ROSE CLAIR      59.9       1      NaN        NaN         NaN
# ...                     ...       ...     ...      ...        ...         ...
# 536843         BEIGE/MARRON  109.0000       1      NaN        NaN         NaN
# 536844               MARRON  129.0000       1      NaN        NaN         NaN
# 536845            GRIS PALE   89.9000       1      NaN        NaN         NaN
# 536846                CAMEL   59.9000      -1    -59.8     0.1669         NaN
# 536847                BEIGE  109.0000      -1    -98.9     9.2661         NaN
#
# [536848 rows x 23 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 536848 entries, 0 to 536847
# Data columns (total 23 columns):
# ID_ORDER        536848 non-null int32
# DATE-ADD        536848 non-null datetime64[ns]
# TIME-ADD        536848 non-null datetime64[ns]
# LOCATION        536848 non-null int32
# ID_CUSTOMER     536848 non-null object
# LAST_NAME       536848 non-null object
# FIRST_NAME      271624 non-null object
# YX_LIBELLE      426416 non-null object
# BIRTH_YEAR      536833 non-null object
# TELEX           267784 non-null object
# EMAIL           134450 non-null object
# ADRESS          177862 non-null object
# POSTAL_CODE     439634 non-null object
# CITY            439129 non-null object
# ITEM_CODE       536847 non-null object
# CC_LIBELLE      536387 non-null object
# CC_LIBELLE_1    536387 non-null object
# DESIGNATION     536387 non-null object
# PVTTC           536848 non-null object
# QTEFACT         536848 non-null object
# PUTTCNET        445275 non-null object
# MLR_REMISE      445214 non-null float64
# GTR_LIBELLE     439960 non-null object
# dtypes: datetime64[ns](2), float64(1), int32(2), object(18)
# memory usage: 90.1+ MB

# %%
# Create the dictionary for  ETABLISSEMENT
etab = {28:'Sasio Geant',31:'Blue Island Carrefour',62:'Central Park',16:'Sousse',8:'Lafayette',130:'Blue Island Palmarium',50:'Sasio Carrefour',24:'Bizerte',40:'Ennasr',56:'Sasio Manzah VI',14:'Blue Island Zephyr',61:'La Soukra',63:'Sasio Menzah V',54:'Nabeul',37:'Sasio Zephyr',134:'Sasio Palmarium',64:'Nabeul',65:'Blue Island Manar',36:'Sasio Manar',25:'Blue Island Djerba',52:'Blue Island Menzah VI',66:'Mehdia',42:'Lac 2',67:'Sfax',68:'Monastir',51:'Blue Island Menzah V',69:'El Kef',35:'Kairouan',15:'Sasio Mseken',27:'Sasio Mseken',60:'Sasio Djerba',18:'Kelibia',41:'Ksar Hellal',74:'Hammamet'}
df['LOCATION'] = df['LOCATION'].map(etab)
#display the first 5 lines
df
# Out:
#         ID_ORDER   DATE-ADD            TIME-ADD            LOCATION  \
# 0       66032518 2018-01-01 2018-01-01 12:06:50              Mehdia
# 1       80143573 2018-01-01 2018-01-01 16:03:37           Lafayette
# 2       80143576 2018-01-01 2018-01-01 17:38:26           Lafayette
# 3       80143572 2018-01-01 2018-01-01 14:52:08           Lafayette
# 4       80143574 2018-01-01 2018-01-01 16:56:04           Lafayette
# ...          ...        ...                 ...                 ...
# 536843  24168599 2018-12-31 2018-12-31 13:40:18             Bizerte
# 536844  24168598 2018-12-31 2018-12-31 13:39:30             Bizerte
# 536845  24168602 2018-12-31 2018-12-31 14:40:15             Bizerte
# 536846  14142423 2018-12-31 2018-12-31 11:04:33  Blue Island Zephyr
# 536847  14142426 2018-12-31 2018-12-31 11:16:19  Blue Island Zephyr
#
#        ID_CUSTOMER          LAST_NAME FIRST_NAME  YX_LIBELLE BIRTH_YEAR  \
# 0         SC000004  CLIENT de PASSAGE        NaN    PASSAGER          0
# 1         SC000004  CLIENT de PASSAGE        NaN    PASSAGER          0
# 2         SC000004  CLIENT de PASSAGE        NaN    PASSAGER          0
# 3         SC000004  CLIENT de PASSAGE        NaN    PASSAGER          0
# 4         SC000004  CLIENT de PASSAGE        NaN    PASSAGER          0
# ...            ...                ...        ...         ...        ...
# 536843    S2020706         BEN HAMIDA      Sonia         NaN       1974
# 536844    S2020706         BEN HAMIDA      Sonia         NaN       1974
# 536845   BC0240557            ZEDDINI       Wael  PARTENAIRE       1900
# 536846   BC0080855             BRAIKI     Mariem  PARTENAIRE       1900
# 536847    SC000004  CLIENT de PASSAGE        NaN    PASSAGER          0
#
#            TELEX  ...      CITY           ITEM_CODE     CC_LIBELLE  \
# 0            NaN  ...     TUNIS    6BL00F051401F18H    SASIO FEMME
# 1            NaN  ...     TUNIS       4PUPH45NRS18H    BLUE ISLAND
# 2            NaN  ...     TUNIS         6CR04NRS18H    SASIO FEMME
# 3            NaN  ...     TUNIS    22BL00FR0501518H  REQUEST FEMME
# 4            NaN  ...     TUNIS    6SW00F071556F18H    SASIO FEMME
# ...          ...  ...       ...                 ...            ...
# 536843  98691207  ...  ZARZOUNA  17CHC00H10830DC19H    ISLAND CLUB
# 536844  98691207  ...  ZARZOUNA   17PA00H111360C19H    ISLAND CLUB
# 536845  21882114  ...       NaN         4PU18CND18H    BLUE ISLAND
# 536846  22494208  ...       NaN    27PA00BS1105219H     BLEU & SON
# 536847       NaN  ...     TUNIS    4PA00H111351F19H    BLUE ISLAND
#
#        CC_LIBELLE_1          DESIGNATION     PVTTC QTEFACT PUTTCNET  \
# 0            BLOUSE                 ROUX      79.9      -1   -39.95
# 1              PULL                 BLEU      79.9       1      NaN
# 2          CARDIGAN     MARINE/ROSE PALE      84.9       1      NaN
# 3            BLOUSE  MARINE/ROSE VIOLINE      49.9       1      NaN
# 4       SWEAT SHIRT           ROSE CLAIR      59.9       1      NaN
# ...             ...                  ...       ...     ...      ...
# 536843      CHEMISE         BEIGE/MARRON  109.0000       1      NaN
# 536844     PANTALON               MARRON  129.0000       1      NaN
# 536845         PULL            GRIS PALE   89.9000       1      NaN
# 536846     PANTALON                CAMEL   59.9000      -1    -59.8
# 536847     PANTALON                BEIGE  109.0000      -1    -98.9
#
#        MLR_REMISE GTR_LIBELLE
# 0         50.0000         NaN
# 1             NaN         NaN
# 2             NaN         NaN
# 3             NaN         NaN
# 4             NaN         NaN
# ...           ...         ...
# 536843        NaN         NaN
# 536844        NaN         NaN
# 536845        NaN         NaN
# 536846     0.1669         NaN
# 536847     9.2661         NaN
#
# [536848 rows x 23 columns]

# %%
df['LOCATION'].value_counts()
# Out:
# Central Park             41495
# Sousse                   37702
# Nabeul                   37591
# Sasio Geant              35923
# Bizerte                  31605
# Blue Island Carrefour    29947
# Lafayette                25563
# Sfax                     20199
# Monastir                 19996
# Blue Island Palmarium    17997
# Kairouan                 17697
# Sasio Manzah VI          17348
# Sasio Carrefour          16039
# Blue Island Zephyr       14134
# Ennasr                   13632
# El Kef                   13615
# Sasio Mseken             13446
# Sasio Palmarium          13233
# Kelibia                  11111
# Mehdia                   11095
# Sasio Menzah V           11068
# Ksar Hellal              10794
# La Soukra                10347
# Sasio Manar              10101
# Hammamet                  9305
# Blue Island Manar         8619
# Sasio Zephyr              7305
# Blue Island Menzah V      6688
# Lac 2                     6264
# Sasio Djerba              6048
# Blue Island Djerba        5751
# Blue Island Menzah VI     5190
# Name: LOCATION, dtype: int64

# %%
df['DATE-ADD'] = pd.to_datetime(df['DATE-ADD'])

df['SEASON'] = (df['DATE-ADD'].dt.month - 1) // 3
df['SEASON'] += (df['DATE-ADD'].dt.month == 3)&(df['DATE-ADD'].dt.day>=20)
df['SEASON'] += (df['DATE-ADD'].dt.month == 6)&(df['DATE-ADD'].dt.day>=21)
df['SEASON'] += (df['DATE-ADD'].dt.month == 9)&(df['DATE-ADD'].dt.day>=23)
df['SEASON'] -= 3*((df['DATE-ADD'].dt.month == 12)&(df['DATE-ADD'].dt.day>=21)).astype(int)

# %%
df.iloc[130766,:]
# Out:
# ID_ORDER                        37017306
# DATE-ADD             2018-03-21 00:00:00
# TIME-ADD             2018-03-21 17:08:07
# LOCATION                    Sasio Zephyr
# ID_CUSTOMER                    SB0370063
# LAST_NAME                       ISMAHENE
# FIRST_NAME                       Khraifi
# YX_LIBELLE                    PARTENAIRE
# BIRTH_YEAR                          1982
# TELEX                           25939290
# EMAIL                                NaN
# ADRESS          33rue Abdelaziz La Marsa
# POSTAL_CODE                          NaN
# CITY                                 NaN
# ITEM_CODE                   6GL1009SL18H
# CC_LIBELLE                   SASIO FEMME
# CC_LIBELLE_1                     TUNIQUE
# DESIGNATION                     MOUTARDE
# PVTTC                            74.9000
# QTEFACT                                1
# PUTTCNET                           22.47
# MLR_REMISE                            70
# GTR_LIBELLE                       Soldes
# SEASON                                 1
# Name: 130766, dtype: object

# %%
season={0:'Winter',1:'Spring',2:'Summer',3:'Autumn'}

df['SEASON'] = df['SEASON'].map(season)
df
# Out:
#         ID_ORDER   DATE-ADD            TIME-ADD            LOCATION  \
# 0       66032518 2018-01-01 2018-01-01 12:06:50              Mehdia
# 1       80143573 2018-01-01 2018-01-01 16:03:37           Lafayette
# 2       80143576 2018-01-01 2018-01-01 17:38:26           Lafayette
# 3       80143572 2018-01-01 2018-01-01 14:52:08           Lafayette
# 4       80143574 2018-01-01 2018-01-01 16:56:04           Lafayette
# ...          ...        ...                 ...                 ...
# 536843  24168599 2018-12-31 2018-12-31 13:40:18             Bizerte
# 536844  24168598 2018-12-31 2018-12-31 13:39:30             Bizerte
# 536845  24168602 2018-12-31 2018-12-31 14:40:15             Bizerte
# 536846  14142423 2018-12-31 2018-12-31 11:04:33  Blue Island Zephyr
# 536847  14142426 2018-12-31 2018-12-31 11:16:19  Blue Island Zephyr
#
#        ID_CUSTOMER          LAST_NAME FIRST_NAME  YX_LIBELLE BIRTH_YEAR  \
# 0         SC000004  CLIENT de PASSAGE        NaN    PASSAGER          0
# 1         SC000004  CLIENT de PASSAGE        NaN    PASSAGER          0
# 2         SC000004  CLIENT de PASSAGE        NaN    PASSAGER          0
# 3         SC000004  CLIENT de PASSAGE        NaN    PASSAGER          0
# 4         SC000004  CLIENT de PASSAGE        NaN    PASSAGER          0
# ...            ...                ...        ...         ...        ...
# 536843    S2020706         BEN HAMIDA      Sonia         NaN       1974
# 536844    S2020706         BEN HAMIDA      Sonia         NaN       1974
# 536845   BC0240557            ZEDDINI       Wael  PARTENAIRE       1900
# 536846   BC0080855             BRAIKI     Mariem  PARTENAIRE       1900
# 536847    SC000004  CLIENT de PASSAGE        NaN    PASSAGER          0
#
#            TELEX  ...           ITEM_CODE     CC_LIBELLE CC_LIBELLE_1  \
# 0            NaN  ...    6BL00F051401F18H    SASIO FEMME       BLOUSE
# 1            NaN  ...       4PUPH45NRS18H    BLUE ISLAND         PULL
# 2            NaN  ...         6CR04NRS18H    SASIO FEMME     CARDIGAN
# 3            NaN  ...    22BL00FR0501518H  REQUEST FEMME       BLOUSE
# 4            NaN  ...    6SW00F071556F18H    SASIO FEMME  SWEAT SHIRT
# ...          ...  ...                 ...            ...          ...
# 536843  98691207  ...  17CHC00H10830DC19H    ISLAND CLUB      CHEMISE
# 536844  98691207  ...   17PA00H111360C19H    ISLAND CLUB     PANTALON
# 536845  21882114  ...         4PU18CND18H    BLUE ISLAND         PULL
# 536846  22494208  ...    27PA00BS1105219H     BLEU & SON     PANTALON
# 536847       NaN  ...    4PA00H111351F19H    BLUE ISLAND     PANTALON
#
#                 DESIGNATION     PVTTC QTEFACT PUTTCNET MLR_REMISE GTR_LIBELLE  \
# 0                      ROUX      79.9      -1   -39.95    50.0000         NaN
# 1                      BLEU      79.9       1      NaN        NaN         NaN
# 2          MARINE/ROSE PALE      84.9       1      NaN        NaN         NaN
# 3       MARINE/ROSE VIOLINE      49.9       1      NaN        NaN         NaN
# 4                ROSE CLAIR      59.9       1      NaN        NaN         NaN
# ...                     ...       ...     ...      ...        ...         ...
# 536843         BEIGE/MARRON  109.0000       1      NaN        NaN         NaN
# 536844               MARRON  129.0000       1      NaN        NaN         NaN
# 536845            GRIS PALE   89.9000       1      NaN        NaN         NaN
# 536846                CAMEL   59.9000      -1    -59.8     0.1669         NaN
# 536847                BEIGE  109.0000      -1    -98.9     9.2661         NaN
#
#         SEASON
# 0       Winter
# 1       Winter
# 2       Winter
# 3       Winter
# 4       Winter
# ...        ...
# 536843  Winter
# 536844  Winter
# 536845  Winter
# 536846  Winter
# 536847  Winter
#
# [536848 rows x 24 columns]

# %%
df = df[['ID_ORDER', 'DATE-ADD','TIME-ADD','SEASON','LOCATION','ID_CUSTOMER','LAST_NAME','FIRST_NAME','YX_LIBELLE','BIRTH_YEAR','TELEX','EMAIL','ADRESS','POSTAL_CODE','CITY','ITEM_CODE','CC_LIBELLE','CC_LIBELLE_1','DESIGNATION','PVTTC','QTEFACT','PUTTCNET','MLR_REMISE','GTR_LIBELLE']]
df
# Out:
#         ID_ORDER   DATE-ADD            TIME-ADD  SEASON            LOCATION  \
# 0       66032518 2018-01-01 2018-01-01 12:06:50  Winter              Mehdia
# 1       80143573 2018-01-01 2018-01-01 16:03:37  Winter           Lafayette
# 2       80143576 2018-01-01 2018-01-01 17:38:26  Winter           Lafayette
# 3       80143572 2018-01-01 2018-01-01 14:52:08  Winter           Lafayette
# 4       80143574 2018-01-01 2018-01-01 16:56:04  Winter           Lafayette
# ...          ...        ...                 ...     ...                 ...
# 536843  24168599 2018-12-31 2018-12-31 13:40:18  Winter             Bizerte
# 536844  24168598 2018-12-31 2018-12-31 13:39:30  Winter             Bizerte
# 536845  24168602 2018-12-31 2018-12-31 14:40:15  Winter             Bizerte
# 536846  14142423 2018-12-31 2018-12-31 11:04:33  Winter  Blue Island Zephyr
# 536847  14142426 2018-12-31 2018-12-31 11:16:19  Winter  Blue Island Zephyr
#
#        ID_CUSTOMER          LAST_NAME FIRST_NAME  YX_LIBELLE BIRTH_YEAR  ...  \
# 0         SC000004  CLIENT de PASSAGE        NaN    PASSAGER          0  ...
# 1         SC000004  CLIENT de PASSAGE        NaN    PASSAGER          0  ...
# 2         SC000004  CLIENT de PASSAGE        NaN    PASSAGER          0  ...
# 3         SC000004  CLIENT de PASSAGE        NaN    PASSAGER          0  ...
# 4         SC000004  CLIENT de PASSAGE        NaN    PASSAGER          0  ...
# ...            ...                ...        ...         ...        ...  ...
# 536843    S2020706         BEN HAMIDA      Sonia         NaN       1974  ...
# 536844    S2020706         BEN HAMIDA      Sonia         NaN       1974  ...
# 536845   BC0240557            ZEDDINI       Wael  PARTENAIRE       1900  ...
# 536846   BC0080855             BRAIKI     Mariem  PARTENAIRE       1900  ...
# 536847    SC000004  CLIENT de PASSAGE        NaN    PASSAGER          0  ...
#
#             CITY           ITEM_CODE     CC_LIBELLE CC_LIBELLE_1  \
# 0          TUNIS    6BL00F051401F18H    SASIO FEMME       BLOUSE
# 1          TUNIS       4PUPH45NRS18H    BLUE ISLAND         PULL
# 2          TUNIS         6CR04NRS18H    SASIO FEMME     CARDIGAN
# 3          TUNIS    22BL00FR0501518H  REQUEST FEMME       BLOUSE
# 4          TUNIS    6SW00F071556F18H    SASIO FEMME  SWEAT SHIRT
# ...          ...                 ...            ...          ...
# 536843  ZARZOUNA  17CHC00H10830DC19H    ISLAND CLUB      CHEMISE
# 536844  ZARZOUNA   17PA00H111360C19H    ISLAND CLUB     PANTALON
# 536845       NaN         4PU18CND18H    BLUE ISLAND         PULL
# 536846       NaN    27PA00BS1105219H     BLEU & SON     PANTALON
# 536847     TUNIS    4PA00H111351F19H    BLUE ISLAND     PANTALON
#
#                 DESIGNATION     PVTTC QTEFACT PUTTCNET MLR_REMISE GTR_LIBELLE
# 0                      ROUX      79.9      -1   -39.95    50.0000         NaN
# 1                      BLEU      79.9       1      NaN        NaN         NaN
# 2          MARINE/ROSE PALE      84.9       1      NaN        NaN         NaN
# 3       MARINE/ROSE VIOLINE      49.9       1      NaN        NaN         NaN
# 4                ROSE CLAIR      59.9       1      NaN        NaN         NaN
# ...                     ...       ...     ...      ...        ...         ...
# 536843         BEIGE/MARRON  109.0000       1      NaN        NaN         NaN
# 536844               MARRON  129.0000       1      NaN        NaN         NaN
# 536845            GRIS PALE   89.9000       1      NaN        NaN         NaN
# 536846                CAMEL   59.9000      -1    -59.8     0.1669         NaN
# 536847                BEIGE  109.0000      -1    -98.9     9.2661         NaN
#
# [536848 rows x 24 columns]

# %%
df.iloc[130850,:]
# Out:
# ID_ORDER                   61063036
# DATE-ADD        2018-03-21 00:00:00
# TIME-ADD        2018-03-21 17:32:41
# SEASON                       Spring
# LOCATION                  La Soukra
# ID_CUSTOMER                SC000004
# LAST_NAME         CLIENT de PASSAGE
# FIRST_NAME                      NaN
# YX_LIBELLE                 PASSAGER
# BIRTH_YEAR                        0
# TELEX                           NaN
# EMAIL                           NaN
# ADRESS                          NaN
# POSTAL_CODE                    1008
# CITY                          TUNIS
# ITEM_CODE              6PON07NRS18H
# CC_LIBELLE              SASIO FEMME
# CC_LIBELLE_1                 PONCHO
# DESIGNATION                  MARINE
# PVTTC                       79.9000
# QTEFACT                           1
# PUTTCNET                      31.96
# MLR_REMISE                       60
# GTR_LIBELLE                  Soldes
# Name: 130850, dtype: object

# %%
df['COVID']='Pre-Covid'
df = df[['ID_ORDER', 'DATE-ADD','TIME-ADD','SEASON','COVID','LOCATION','ID_CUSTOMER','LAST_NAME','FIRST_NAME','YX_LIBELLE','BIRTH_YEAR','TELEX','EMAIL','ADRESS','POSTAL_CODE','CITY','ITEM_CODE','CC_LIBELLE','CC_LIBELLE_1','DESIGNATION','PVTTC','QTEFACT','PUTTCNET','MLR_REMISE','GTR_LIBELLE']]
df
# Out:
# C:\Users\sofi\Anacondaa\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#         ID_ORDER   DATE-ADD            TIME-ADD  SEASON      COVID  \
# 0       66032518 2018-01-01 2018-01-01 12:06:50  Winter  Pre-Covid
# 1       80143573 2018-01-01 2018-01-01 16:03:37  Winter  Pre-Covid
# 2       80143576 2018-01-01 2018-01-01 17:38:26  Winter  Pre-Covid
# 3       80143572 2018-01-01 2018-01-01 14:52:08  Winter  Pre-Covid
# 4       80143574 2018-01-01 2018-01-01 16:56:04  Winter  Pre-Covid
# ...          ...        ...                 ...     ...        ...
# 536843  24168599 2018-12-31 2018-12-31 13:40:18  Winter  Pre-Covid
# 536844  24168598 2018-12-31 2018-12-31 13:39:30  Winter  Pre-Covid
# 536845  24168602 2018-12-31 2018-12-31 14:40:15  Winter  Pre-Covid
# 536846  14142423 2018-12-31 2018-12-31 11:04:33  Winter  Pre-Covid
# 536847  14142426 2018-12-31 2018-12-31 11:16:19  Winter  Pre-Covid
#
#                   LOCATION ID_CUSTOMER          LAST_NAME FIRST_NAME  \
# 0                   Mehdia    SC000004  CLIENT de PASSAGE        NaN
# 1                Lafayette    SC000004  CLIENT de PASSAGE        NaN
# 2                Lafayette    SC000004  CLIENT de PASSAGE        NaN
# 3                Lafayette    SC000004  CLIENT de PASSAGE        NaN
# 4                Lafayette    SC000004  CLIENT de PASSAGE        NaN
# ...                    ...         ...                ...        ...
# 536843             Bizerte    S2020706         BEN HAMIDA      Sonia
# 536844             Bizerte    S2020706         BEN HAMIDA      Sonia
# 536845             Bizerte   BC0240557            ZEDDINI       Wael
# 536846  Blue Island Zephyr   BC0080855             BRAIKI     Mariem
# 536847  Blue Island Zephyr    SC000004  CLIENT de PASSAGE        NaN
#
#         YX_LIBELLE  ...      CITY           ITEM_CODE     CC_LIBELLE  \
# 0         PASSAGER  ...     TUNIS    6BL00F051401F18H    SASIO FEMME
# 1         PASSAGER  ...     TUNIS       4PUPH45NRS18H    BLUE ISLAND
# 2         PASSAGER  ...     TUNIS         6CR04NRS18H    SASIO FEMME
# 3         PASSAGER  ...     TUNIS    22BL00FR0501518H  REQUEST FEMME
# 4         PASSAGER  ...     TUNIS    6SW00F071556F18H    SASIO FEMME
# ...            ...  ...       ...                 ...            ...
# 536843         NaN  ...  ZARZOUNA  17CHC00H10830DC19H    ISLAND CLUB
# 536844         NaN  ...  ZARZOUNA   17PA00H111360C19H    ISLAND CLUB
# 536845  PARTENAIRE  ...       NaN         4PU18CND18H    BLUE ISLAND
# 536846  PARTENAIRE  ...       NaN    27PA00BS1105219H     BLEU & SON
# 536847    PASSAGER  ...     TUNIS    4PA00H111351F19H    BLUE ISLAND
#
#        CC_LIBELLE_1          DESIGNATION     PVTTC QTEFACT PUTTCNET  \
# 0            BLOUSE                 ROUX      79.9      -1   -39.95
# 1              PULL                 BLEU      79.9       1      NaN
# 2          CARDIGAN     MARINE/ROSE PALE      84.9       1      NaN
# 3            BLOUSE  MARINE/ROSE VIOLINE      49.9       1      NaN
# 4       SWEAT SHIRT           ROSE CLAIR      59.9       1      NaN
# ...             ...                  ...       ...     ...      ...
# 536843      CHEMISE         BEIGE/MARRON  109.0000       1      NaN
# 536844     PANTALON               MARRON  129.0000       1      NaN
# 536845         PULL            GRIS PALE   89.9000       1      NaN
# 536846     PANTALON                CAMEL   59.9000      -1    -59.8
# 536847     PANTALON                BEIGE  109.0000      -1    -98.9
#
#        MLR_REMISE GTR_LIBELLE
# 0         50.0000         NaN
# 1             NaN         NaN
# 2             NaN         NaN
# 3             NaN         NaN
# 4             NaN         NaN
# ...           ...         ...
# 536843        NaN         NaN
# 536844        NaN         NaN
# 536845        NaN         NaN
# 536846     0.1669         NaN
# 536847     9.2661         NaN
#
# [536848 rows x 25 columns]

# %%
df['BIRTH_YEAR'] = pd.to_datetime(df['BIRTH_YEAR'],errors='coerce')

# %%
df.isnull().sum()
# Out:
# ID_ORDER               0
# DATE-ADD               0
# TIME-ADD               0
# HOUR                   0
# SEASON                 0
# P_MONTH                0
# P_WEEK                 0
# COVID                  0
# CONFINEMENT            0
# CURFEW                 0
# LOCATION               0
# ID_CUSTOMER            0
# LAST_NAME              0
# FIRST_NAME        265224
# YX_LIBELLE        110432
# BIRTH_YEAR             0
# AGE                    8
# TELEX             269064
# EMAIL             402398
# ADRESS            358986
# POSTAL_CODE            0
# CITY               97719
# ITEM_CODE              1
# CC_LIBELLE           461
# CC_LIBELLE_1         461
# DESIGNATION          461
# PVTTC                  0
# QTEFACT                0
# PUTTCNET           91573
# MLR_REMISE         91634
# GTR_LIBELLE        96888
# TOTAL_QUANTITY         0
# REGION            102338
# AREA              102338
# CLASS             102338
# dtype: int64

# %%
df['BIRTH_YEAR'].fillna((df['BIRTH_YEAR'].mean()), inplace=True)

# %%
df.isnull().sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-629914d6d1c7> in <module>
# ----> 1 df.isnull().sum()
#
# NameError: name 'df' is not defined

# %%
df[df['BIRTH_YEAR']=='2099']
df[df['BIRTH_YEAR']=='1765']
df[df['BIRTH_YEAR']=='1775']
# Out:
#         ID_ORDER   DATE-ADD            TIME-ADD  SEASON      COVID  \
# 225346  62213164 2018-06-10 2018-06-10 15:13:27  Spring  Pre-Covid
#
#             LOCATION ID_CUSTOMER LAST_NAME FIRST_NAME  YX_LIBELLE  ... CITY  \
# 225346  Central Park   SB0621595     MAHDI    El Behi  PARTENAIRE  ...  NaN
#
#                ITEM_CODE   CC_LIBELLE CC_LIBELLE_1 DESIGNATION    PVTTC  \
# 225346  4TS00H171286F18E  BLUE ISLAND    TEE-SHIRT  BLANC/BLEU  34.9000
#
#        QTEFACT PUTTCNET MLR_REMISE                GTR_LIBELLE
# 225346  1.0000    31.41       10.0  Offre Speciale FidÃ©litÃ©
#
# [1 rows x 25 columns]

# %%
df.loc[262694,'BIRTH_YEAR'] =None
df.loc[136790,'BIRTH_YEAR'] =None
df.loc[138972,'BIRTH_YEAR'] =None
df.loc[146290,'BIRTH_YEAR'] =None
df.loc[146311,'BIRTH_YEAR'] =None
df.loc[147012,'BIRTH_YEAR'] =None
df.loc[147087,'BIRTH_YEAR'] =None
df.loc[225346,'BIRTH_YEAR'] =None

# %%
from datetime import datetime, timedelta
df.loc[((df.BIRTH_YEAR).dt.year < 1018),'BIRTH_YEAR']=None

# %%
df['AGE'] = df['DATE-ADD'].dt.year- df['BIRTH_YEAR'].dt.year
df
# Out:
#         ID_ORDER   DATE-ADD            TIME-ADD  SEASON      COVID  \
# 0       66032518 2018-01-01 2018-01-01 12:06:50  Winter  Pre-Covid
# 1       80143573 2018-01-01 2018-01-01 16:03:37  Winter  Pre-Covid
# 2       80143576 2018-01-01 2018-01-01 17:38:26  Winter  Pre-Covid
# 3       80143572 2018-01-01 2018-01-01 14:52:08  Winter  Pre-Covid
# 4       80143574 2018-01-01 2018-01-01 16:56:04  Winter  Pre-Covid
# ...          ...        ...                 ...     ...        ...
# 536843  24168599 2018-12-31 2018-12-31 13:40:18  Winter  Pre-Covid
# 536844  24168598 2018-12-31 2018-12-31 13:39:30  Winter  Pre-Covid
# 536845  24168602 2018-12-31 2018-12-31 14:40:15  Winter  Pre-Covid
# 536846  14142423 2018-12-31 2018-12-31 11:04:33  Winter  Pre-Covid
# 536847  14142426 2018-12-31 2018-12-31 11:16:19  Winter  Pre-Covid
#
#                   LOCATION ID_CUSTOMER          LAST_NAME FIRST_NAME  \
# 0                   Mehdia    SC000004  CLIENT de PASSAGE        NaN
# 1                Lafayette    SC000004  CLIENT de PASSAGE        NaN
# 2                Lafayette    SC000004  CLIENT de PASSAGE        NaN
# 3                Lafayette    SC000004  CLIENT de PASSAGE        NaN
# 4                Lafayette    SC000004  CLIENT de PASSAGE        NaN
# ...                    ...         ...                ...        ...
# 536843             Bizerte    S2020706         BEN HAMIDA      Sonia
# 536844             Bizerte    S2020706         BEN HAMIDA      Sonia
# 536845             Bizerte   BC0240557            ZEDDINI       Wael
# 536846  Blue Island Zephyr   BC0080855             BRAIKI     Mariem
# 536847  Blue Island Zephyr    SC000004  CLIENT de PASSAGE        NaN
#
#         YX_LIBELLE  ...           ITEM_CODE     CC_LIBELLE CC_LIBELLE_1  \
# 0         PASSAGER  ...    6BL00F051401F18H    SASIO FEMME       BLOUSE
# 1         PASSAGER  ...       4PUPH45NRS18H    BLUE ISLAND         PULL
# 2         PASSAGER  ...         6CR04NRS18H    SASIO FEMME     CARDIGAN
# 3         PASSAGER  ...    22BL00FR0501518H  REQUEST FEMME       BLOUSE
# 4         PASSAGER  ...    6SW00F071556F18H    SASIO FEMME  SWEAT SHIRT
# ...            ...  ...                 ...            ...          ...
# 536843         NaN  ...  17CHC00H10830DC19H    ISLAND CLUB      CHEMISE
# 536844         NaN  ...   17PA00H111360C19H    ISLAND CLUB     PANTALON
# 536845  PARTENAIRE  ...         4PU18CND18H    BLUE ISLAND         PULL
# 536846  PARTENAIRE  ...    27PA00BS1105219H     BLEU & SON     PANTALON
# 536847    PASSAGER  ...    4PA00H111351F19H    BLUE ISLAND     PANTALON
#
#                 DESIGNATION     PVTTC QTEFACT PUTTCNET MLR_REMISE GTR_LIBELLE  \
# 0                      ROUX      79.9      -1   -39.95    50.0000         NaN
# 1                      BLEU      79.9       1      NaN        NaN         NaN
# 2          MARINE/ROSE PALE      84.9       1      NaN        NaN         NaN
# 3       MARINE/ROSE VIOLINE      49.9       1      NaN        NaN         NaN
# 4                ROSE CLAIR      59.9       1      NaN        NaN         NaN
# ...                     ...       ...     ...      ...        ...         ...
# 536843         BEIGE/MARRON  109.0000       1      NaN        NaN         NaN
# 536844               MARRON  129.0000       1      NaN        NaN         NaN
# 536845            GRIS PALE   89.9000       1      NaN        NaN         NaN
# 536846                CAMEL   59.9000      -1    -59.8     0.1669         NaN
# 536847                BEIGE  109.0000      -1    -98.9     9.2661         NaN
#
#           AGE
# 0        65.0
# 1        65.0
# 2        65.0
# 3        65.0
# 4        65.0
# ...       ...
# 536843   44.0
# 536844   44.0
# 536845  118.0
# 536846  118.0
# 536847   65.0
#
# [536848 rows x 26 columns]

# %%
df = df[['ID_ORDER', 'DATE-ADD','TIME-ADD','SEASON','COVID','LOCATION','ID_CUSTOMER','LAST_NAME','FIRST_NAME','YX_LIBELLE','BIRTH_YEAR','AGE','TELEX','EMAIL','ADRESS','POSTAL_CODE','CITY','ITEM_CODE','CC_LIBELLE','CC_LIBELLE_1','DESIGNATION','PVTTC','QTEFACT','PUTTCNET','MLR_REMISE','GTR_LIBELLE']]

# %%
df['AGE']=df['AGE']
df['AGE'].value_counts()
# Out:
# 65.0     319955
# 118.0     66840
# 38.0      10153
# 39.0       6569
# 40.0       6430
#           ...
# 127.0         2
# 122.0         1
# 80.0          1
# 148.0         1
# 116.0         1
# Name: AGE, Length: 113, dtype: int64

# %%
df['AGE'].value_counts()
# Out:
# 65.0     319955
# 118.0     66840
# 38.0      10153
# 39.0       6569
# 40.0       6430
#           ...
# 127.0         2
# 122.0         1
# 80.0          1
# 148.0         1
# 116.0         1
# Name: AGE, Length: 113, dtype: int64

# %%
df['AGE'].max()
# Out:
# 159.0

# %%
df['AGE'].min()
# Out:
# 0.0

# %%
q1=df["AGE"].quantile(q=0.25)
q3=df["AGE"].quantile(q=0.75)
IQR=q3-q1
borne_inf = q1-1.5*IQR
borne_sup = q3 +1.5*IQR
df.loc[df.AGE>borne_sup,'AGE']=df["AGE"].mean()
df.loc[df.AGE<borne_inf,'AGE']=df["AGE"].mean()
#df= df[df["age"]<borne_sup]
#df=df[df["age"]>borne_inf]

# %%
df['AGE'].max()
# Out:
# 84.0

# %%
df['AGE'].min()
# Out:
# 33.0

# %%
df['CONFINEMENT']='NO'
df['CURFEW']='NO'
df = df[['ID_ORDER', 'DATE-ADD','TIME-ADD','SEASON','COVID','CONFINEMENT','CURFEW','LOCATION','ID_CUSTOMER','LAST_NAME','FIRST_NAME','YX_LIBELLE','BIRTH_YEAR','AGE','TELEX','EMAIL','ADRESS','POSTAL_CODE','CITY','ITEM_CODE','CC_LIBELLE','CC_LIBELLE_1','DESIGNATION','PVTTC','QTEFACT','PUTTCNET','MLR_REMISE','GTR_LIBELLE']]
df
# Out:
#         ID_ORDER   DATE-ADD            TIME-ADD  SEASON      COVID  \
# 0       66032518 2018-01-01 2018-01-01 12:06:50  Winter  Pre-Covid
# 1       80143573 2018-01-01 2018-01-01 16:03:37  Winter  Pre-Covid
# 2       80143576 2018-01-01 2018-01-01 17:38:26  Winter  Pre-Covid
# 3       80143572 2018-01-01 2018-01-01 14:52:08  Winter  Pre-Covid
# 4       80143574 2018-01-01 2018-01-01 16:56:04  Winter  Pre-Covid
# ...          ...        ...                 ...     ...        ...
# 536843  24168599 2018-12-31 2018-12-31 13:40:18  Winter  Pre-Covid
# 536844  24168598 2018-12-31 2018-12-31 13:39:30  Winter  Pre-Covid
# 536845  24168602 2018-12-31 2018-12-31 14:40:15  Winter  Pre-Covid
# 536846  14142423 2018-12-31 2018-12-31 11:04:33  Winter  Pre-Covid
# 536847  14142426 2018-12-31 2018-12-31 11:16:19  Winter  Pre-Covid
#
#        CONFINEMENT CURFEW            LOCATION ID_CUSTOMER          LAST_NAME  \
# 0               NO     NO              Mehdia    SC000004  CLIENT de PASSAGE
# 1               NO     NO           Lafayette    SC000004  CLIENT de PASSAGE
# 2               NO     NO           Lafayette    SC000004  CLIENT de PASSAGE
# 3               NO     NO           Lafayette    SC000004  CLIENT de PASSAGE
# 4               NO     NO           Lafayette    SC000004  CLIENT de PASSAGE
# ...            ...    ...                 ...         ...                ...
# 536843          NO     NO             Bizerte    S2020706         BEN HAMIDA
# 536844          NO     NO             Bizerte    S2020706         BEN HAMIDA
# 536845          NO     NO             Bizerte   BC0240557            ZEDDINI
# 536846          NO     NO  Blue Island Zephyr   BC0080855             BRAIKI
# 536847          NO     NO  Blue Island Zephyr    SC000004  CLIENT de PASSAGE
#
#         ...      CITY           ITEM_CODE     CC_LIBELLE  CC_LIBELLE_1  \
# 0       ...     TUNIS    6BL00F051401F18H    SASIO FEMME        BLOUSE
# 1       ...     TUNIS       4PUPH45NRS18H    BLUE ISLAND          PULL
# 2       ...     TUNIS         6CR04NRS18H    SASIO FEMME      CARDIGAN
# 3       ...     TUNIS    22BL00FR0501518H  REQUEST FEMME        BLOUSE
# 4       ...     TUNIS    6SW00F071556F18H    SASIO FEMME   SWEAT SHIRT
# ...     ...       ...                 ...            ...           ...
# 536843  ...  ZARZOUNA  17CHC00H10830DC19H    ISLAND CLUB       CHEMISE
# 536844  ...  ZARZOUNA   17PA00H111360C19H    ISLAND CLUB      PANTALON
# 536845  ...       NaN         4PU18CND18H    BLUE ISLAND          PULL
# 536846  ...       NaN    27PA00BS1105219H     BLEU & SON      PANTALON
# 536847  ...     TUNIS    4PA00H111351F19H    BLUE ISLAND      PANTALON
#
#                 DESIGNATION     PVTTC QTEFACT PUTTCNET MLR_REMISE GTR_LIBELLE
# 0                      ROUX      79.9      -1   -39.95    50.0000         NaN
# 1                      BLEU      79.9       1      NaN        NaN         NaN
# 2          MARINE/ROSE PALE      84.9       1      NaN        NaN         NaN
# 3       MARINE/ROSE VIOLINE      49.9       1      NaN        NaN         NaN
# 4                ROSE CLAIR      59.9       1      NaN        NaN         NaN
# ...                     ...       ...     ...      ...        ...         ...
# 536843         BEIGE/MARRON  109.0000       1      NaN        NaN         NaN
# 536844               MARRON  129.0000       1      NaN        NaN         NaN
# 536845            GRIS PALE   89.9000       1      NaN        NaN         NaN
# 536846                CAMEL   59.9000      -1    -59.8     0.1669         NaN
# 536847                BEIGE  109.0000      -1    -98.9     9.2661         NaN
#
# [536848 rows x 28 columns]

# %%
df['P_MONTH']=0
df['P_MONTH']+=(df['DATE-ADD'].dt.day>10)
df['P_MONTH']+=(df['DATE-ADD'].dt.day>20)
df['P_MONTH']=df['P_MONTH'].astype(int)

# %%
month={0:'Start_of_Month',1:'Middle_of_Month',2:'End_of_Month'}
df['P_MONTH'] = df['P_MONTH'].map(month)

# %%
df = df[['ID_ORDER', 'DATE-ADD','TIME-ADD','SEASON','P_MONTH','COVID','CONFINEMENT','CURFEW','LOCATION','ID_CUSTOMER','LAST_NAME','FIRST_NAME','YX_LIBELLE','BIRTH_YEAR','AGE','TELEX','EMAIL','ADRESS','POSTAL_CODE','CITY','ITEM_CODE','CC_LIBELLE','CC_LIBELLE_1','DESIGNATION','PVTTC','QTEFACT','PUTTCNET','MLR_REMISE','GTR_LIBELLE']]
df
# Out:
#         ID_ORDER   DATE-ADD            TIME-ADD  SEASON         P_MONTH  \
# 0       66032518 2018-01-01 2018-01-01 12:06:50  Winter  Start_of_Month
# 1       80143573 2018-01-01 2018-01-01 16:03:37  Winter  Start_of_Month
# 2       80143576 2018-01-01 2018-01-01 17:38:26  Winter  Start_of_Month
# 3       80143572 2018-01-01 2018-01-01 14:52:08  Winter  Start_of_Month
# 4       80143574 2018-01-01 2018-01-01 16:56:04  Winter  Start_of_Month
# ...          ...        ...                 ...     ...             ...
# 536843  24168599 2018-12-31 2018-12-31 13:40:18  Winter    End_of_Month
# 536844  24168598 2018-12-31 2018-12-31 13:39:30  Winter    End_of_Month
# 536845  24168602 2018-12-31 2018-12-31 14:40:15  Winter    End_of_Month
# 536846  14142423 2018-12-31 2018-12-31 11:04:33  Winter    End_of_Month
# 536847  14142426 2018-12-31 2018-12-31 11:16:19  Winter    End_of_Month
#
#             COVID CONFINEMENT CURFEW            LOCATION ID_CUSTOMER  ...  \
# 0       Pre-Covid          NO     NO              Mehdia    SC000004  ...
# 1       Pre-Covid          NO     NO           Lafayette    SC000004  ...
# 2       Pre-Covid          NO     NO           Lafayette    SC000004  ...
# 3       Pre-Covid          NO     NO           Lafayette    SC000004  ...
# 4       Pre-Covid          NO     NO           Lafayette    SC000004  ...
# ...           ...         ...    ...                 ...         ...  ...
# 536843  Pre-Covid          NO     NO             Bizerte    S2020706  ...
# 536844  Pre-Covid          NO     NO             Bizerte    S2020706  ...
# 536845  Pre-Covid          NO     NO             Bizerte   BC0240557  ...
# 536846  Pre-Covid          NO     NO  Blue Island Zephyr   BC0080855  ...
# 536847  Pre-Covid          NO     NO  Blue Island Zephyr    SC000004  ...
#
#             CITY           ITEM_CODE     CC_LIBELLE CC_LIBELLE_1  \
# 0          TUNIS    6BL00F051401F18H    SASIO FEMME       BLOUSE
# 1          TUNIS       4PUPH45NRS18H    BLUE ISLAND         PULL
# 2          TUNIS         6CR04NRS18H    SASIO FEMME     CARDIGAN
# 3          TUNIS    22BL00FR0501518H  REQUEST FEMME       BLOUSE
# 4          TUNIS    6SW00F071556F18H    SASIO FEMME  SWEAT SHIRT
# ...          ...                 ...            ...          ...
# 536843  ZARZOUNA  17CHC00H10830DC19H    ISLAND CLUB      CHEMISE
# 536844  ZARZOUNA   17PA00H111360C19H    ISLAND CLUB     PANTALON
# 536845       NaN         4PU18CND18H    BLUE ISLAND         PULL
# 536846       NaN    27PA00BS1105219H     BLEU & SON     PANTALON
# 536847     TUNIS    4PA00H111351F19H    BLUE ISLAND     PANTALON
#
#                 DESIGNATION     PVTTC QTEFACT PUTTCNET MLR_REMISE GTR_LIBELLE
# 0                      ROUX      79.9      -1   -39.95    50.0000         NaN
# 1                      BLEU      79.9       1      NaN        NaN         NaN
# 2          MARINE/ROSE PALE      84.9       1      NaN        NaN         NaN
# 3       MARINE/ROSE VIOLINE      49.9       1      NaN        NaN         NaN
# 4                ROSE CLAIR      59.9       1      NaN        NaN         NaN
# ...                     ...       ...     ...      ...        ...         ...
# 536843         BEIGE/MARRON  109.0000       1      NaN        NaN         NaN
# 536844               MARRON  129.0000       1      NaN        NaN         NaN
# 536845            GRIS PALE   89.9000       1      NaN        NaN         NaN
# 536846                CAMEL   59.9000      -1    -59.8     0.1669         NaN
# 536847                BEIGE  109.0000      -1    -98.9     9.2661         NaN
#
# [536848 rows x 29 columns]

# %%
from datetime import date
import calendar


df['P_WEEK']=df['DATE-ADD'].dt.strftime('%A')
week={'Monday':'Start_of_Week','Tuesday':'Start_of_Week','Wednesday':'Mid_Week','Thursday':'Mid_Week','Friday':'Mid_Week','Saturday':'Week_End','Sunday':'Week_end'}
df['P_WEEK'] = df['P_WEEK'].map(week)
# Out:
# C:\Users\sofi\Anacondaa\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# C:\Users\sofi\Anacondaa\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys

# %%
df = df[['ID_ORDER', 'DATE-ADD','TIME-ADD','SEASON','P_MONTH','P_WEEK','COVID','CONFINEMENT','CURFEW','LOCATION','ID_CUSTOMER','LAST_NAME','FIRST_NAME','YX_LIBELLE','BIRTH_YEAR','AGE','TELEX','EMAIL','ADRESS','POSTAL_CODE','CITY','ITEM_CODE','CC_LIBELLE','CC_LIBELLE_1','DESIGNATION','PVTTC','QTEFACT','PUTTCNET','MLR_REMISE','GTR_LIBELLE']]
df.iloc[130850,:]
# Out:
# ID_ORDER                             61063036
# DATE-ADD                  2018-03-21 00:00:00
# TIME-ADD                  2018-03-21 17:32:41
# SEASON                                 Spring
# P_MONTH                          End_of_Month
# P_WEEK                               Mid_Week
# COVID                               Pre-Covid
# CONFINEMENT                                NO
# CURFEW                                     NO
# LOCATION                            La Soukra
# ID_CUSTOMER                          SC000004
# LAST_NAME                   CLIENT de PASSAGE
# FIRST_NAME                                NaN
# YX_LIBELLE                           PASSAGER
# BIRTH_YEAR      1953-10-31 12:04:51.382066496
# AGE                                        65
# TELEX                                     NaN
# EMAIL                                     NaN
# ADRESS                                    NaN
# POSTAL_CODE                              1008
# CITY                                    TUNIS
# ITEM_CODE                        6PON07NRS18H
# CC_LIBELLE                        SASIO FEMME
# CC_LIBELLE_1                           PONCHO
# DESIGNATION                            MARINE
# PVTTC                                 79.9000
# QTEFACT                                     1
# PUTTCNET                                31.96
# MLR_REMISE                                 60
# GTR_LIBELLE                            Soldes
# Name: 130850, dtype: object

# %%
df['TOTAL_QUANTITY'] = df.groupby(['ID_ORDER'])['DATE-ADD'].transform('count')
df
# Out:
# C:\Users\sofi\Anacondaa\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#         ID_ORDER   DATE-ADD            TIME-ADD  SEASON         P_MONTH  \
# 0       66032518 2018-01-01 2018-01-01 12:06:50  Winter  Start_of_Month
# 1       80143573 2018-01-01 2018-01-01 16:03:37  Winter  Start_of_Month
# 2       80143576 2018-01-01 2018-01-01 17:38:26  Winter  Start_of_Month
# 3       80143572 2018-01-01 2018-01-01 14:52:08  Winter  Start_of_Month
# 4       80143574 2018-01-01 2018-01-01 16:56:04  Winter  Start_of_Month
# ...          ...        ...                 ...     ...             ...
# 536843  24168599 2018-12-31 2018-12-31 13:40:18  Winter    End_of_Month
# 536844  24168598 2018-12-31 2018-12-31 13:39:30  Winter    End_of_Month
# 536845  24168602 2018-12-31 2018-12-31 14:40:15  Winter    End_of_Month
# 536846  14142423 2018-12-31 2018-12-31 11:04:33  Winter    End_of_Month
# 536847  14142426 2018-12-31 2018-12-31 11:16:19  Winter    End_of_Month
#
#                P_WEEK      COVID CONFINEMENT CURFEW            LOCATION  ...  \
# 0       Start_of_Week  Pre-Covid          NO     NO              Mehdia  ...
# 1       Start_of_Week  Pre-Covid          NO     NO           Lafayette  ...
# 2       Start_of_Week  Pre-Covid          NO     NO           Lafayette  ...
# 3       Start_of_Week  Pre-Covid          NO     NO           Lafayette  ...
# 4       Start_of_Week  Pre-Covid          NO     NO           Lafayette  ...
# ...               ...        ...         ...    ...                 ...  ...
# 536843  Start_of_Week  Pre-Covid          NO     NO             Bizerte  ...
# 536844  Start_of_Week  Pre-Covid          NO     NO             Bizerte  ...
# 536845  Start_of_Week  Pre-Covid          NO     NO             Bizerte  ...
# 536846  Start_of_Week  Pre-Covid          NO     NO  Blue Island Zephyr  ...
# 536847  Start_of_Week  Pre-Covid          NO     NO  Blue Island Zephyr  ...
#
#                  ITEM_CODE     CC_LIBELLE CC_LIBELLE_1          DESIGNATION  \
# 0         6BL00F051401F18H    SASIO FEMME       BLOUSE                 ROUX
# 1            4PUPH45NRS18H    BLUE ISLAND         PULL                 BLEU
# 2              6CR04NRS18H    SASIO FEMME     CARDIGAN     MARINE/ROSE PALE
# 3         22BL00FR0501518H  REQUEST FEMME       BLOUSE  MARINE/ROSE VIOLINE
# 4         6SW00F071556F18H    SASIO FEMME  SWEAT SHIRT           ROSE CLAIR
# ...                    ...            ...          ...                  ...
# 536843  17CHC00H10830DC19H    ISLAND CLUB      CHEMISE         BEIGE/MARRON
# 536844   17PA00H111360C19H    ISLAND CLUB     PANTALON               MARRON
# 536845         4PU18CND18H    BLUE ISLAND         PULL            GRIS PALE
# 536846    27PA00BS1105219H     BLEU & SON     PANTALON                CAMEL
# 536847    4PA00H111351F19H    BLUE ISLAND     PANTALON                BEIGE
#
#            PVTTC  QTEFACT PUTTCNET MLR_REMISE GTR_LIBELLE TOTAL_QUANTITY
# 0           79.9       -1   -39.95    50.0000         NaN              4
# 1           79.9        1      NaN        NaN         NaN              1
# 2           84.9        1      NaN        NaN         NaN              2
# 3           49.9        1      NaN        NaN         NaN              1
# 4           59.9        1      NaN        NaN         NaN              1
# ...          ...      ...      ...        ...         ...            ...
# 536843  109.0000        1      NaN        NaN         NaN              2
# 536844  129.0000        1      NaN        NaN         NaN              2
# 536845   89.9000        1      NaN        NaN         NaN              2
# 536846   59.9000       -1    -59.8     0.1669         NaN              5
# 536847  109.0000       -1    -98.9     9.2661         NaN              2
#
# [536848 rows x 31 columns]

# %%
df[df['ID_ORDER'] ==66032518]
# Out:
#      ID_ORDER   DATE-ADD            TIME-ADD  SEASON         P_MONTH  \
# 0    66032518 2018-01-01 2018-01-01 12:06:50  Winter  Start_of_Month
# 186  66032518 2018-01-01 2018-01-01 12:06:50  Winter  Start_of_Month
# 187  66032518 2018-01-01 2018-01-01 12:06:50  Winter  Start_of_Month
# 356  66032518 2018-01-01 2018-01-01 12:06:50  Winter  Start_of_Month
#
#             P_WEEK      COVID CONFINEMENT CURFEW LOCATION  ...  \
# 0    Start_of_Week  Pre-Covid          NO     NO   Mehdia  ...
# 186  Start_of_Week  Pre-Covid          NO     NO   Mehdia  ...
# 187  Start_of_Week  Pre-Covid          NO     NO   Mehdia  ...
# 356  Start_of_Week  Pre-Covid          NO     NO   Mehdia  ...
#
#             ITEM_CODE     CC_LIBELLE CC_LIBELLE_1          DESIGNATION  PVTTC  \
# 0    6BL00F051401F18H    SASIO FEMME       BLOUSE                 ROUX   79.9
# 186    15PA00ROS9118H          IPSOS     PANTALON                 NOIR   98.9
# 187    15VE00ROS9018H          IPSOS        VESTE               VIOLET  169.9
# 356  22BL00FR0501518H  REQUEST FEMME       BLOUSE  MARINE/ROSE VIOLINE   49.9
#
#      QTEFACT PUTTCNET MLR_REMISE               GTR_LIBELLE TOTAL_QUANTITY
# 0         -1   -39.95       50.0                       NaN              4
# 186       -1      NaN        NaN                       NaN              4
# 187        1      NaN        NaN                       NaN              4
# 356        1    24.95       50.0  2 eme 50 et le 3 eme 100              4
#
# [4 rows x 31 columns]

# %%
df2= pd.read_csv(r'C:\Users\sofi\Downloads\train_code_postal.csv')
df2 = df2.rename(columns={'code postal': 'POST_CODE'})
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 969 entries, 0 to 968
# Data columns (total 5 columns):
# POST_CODE       969 non-null object
# Delegation      969 non-null object
# poverty rate    969 non-null float64
# zone            969 non-null object
# orientation     969 non-null object
# dtypes: float64(1), object(4)
# memory usage: 38.0+ KB

# %%
df['QTEFACT'].value_counts()
# Out:
# 1.0           363489
# 1.0000        158783
# -1.0            9031
# -1.0000         4888
# 89.9              60
#                ...
# PRUNE/NOIR         1
# 159.0              1
# 139.0              1
# 389.0              1
# 0.0                1
# Name: QTEFACT, Length: 90, dtype: int64

# %%
df[df['QTEFACT'] ==89.9]
# Out:
#          ID_ORDER   DATE-ADD            TIME-ADD  SEASON          P_MONTH  \
# 34265   410008714 2018-01-31 2018-01-31 11:44:42  Winter     End_of_Month
# 65879    54131936 2018-02-17 2018-02-17 15:39:51  Winter  Middle_of_Month
# 69132   640070187 2018-02-20 2018-02-20 17:18:30  Winter  Middle_of_Month
# 73001   640070224 2018-02-22 2018-02-23 19:04:02  Winter     End_of_Month
# 73292   640070224 2018-02-22 2018-02-23 19:04:02  Winter     End_of_Month
# 90228    54132258 2018-02-26 2018-02-26 18:00:24  Winter     End_of_Month
# 96664   640070435 2018-02-28 2018-02-28 16:52:57  Winter     End_of_Month
# 96665   640070435 2018-02-28 2018-02-28 16:52:57  Winter     End_of_Month
# 96763   640070435 2018-02-28 2018-02-28 16:52:57  Winter     End_of_Month
# 96781   640070435 2018-02-28 2018-02-28 16:52:57  Winter     End_of_Month
# 96782   640070435 2018-02-28 2018-02-28 16:52:57  Winter     End_of_Month
# 96944   640070435 2018-02-28 2018-02-28 16:52:57  Winter     End_of_Month
# 114883  640070637 2018-03-07 2018-03-07 19:23:42  Winter   Start_of_Month
# 119431  640070725 2018-03-11 2018-03-11 13:18:34  Winter  Middle_of_Month
# 121665  640070788 2018-03-14 2018-03-14 18:54:45  Winter  Middle_of_Month
# 124140  640070825 2018-03-16 2018-03-16 19:10:29  Winter  Middle_of_Month
# 127023  640070865 2018-03-18 2018-03-18 19:01:19  Winter  Middle_of_Month
# 128554  640070879 2018-03-19 2018-03-19 16:56:37  Winter  Middle_of_Month
# 128596  640070877 2018-03-19 2018-03-19 16:15:46  Winter  Middle_of_Month
# 129336  640070900 2018-03-20 2018-03-20 15:13:28  Spring  Middle_of_Month
# 133513  640070970 2018-03-23 2018-03-23 18:52:43  Spring     End_of_Month
# 133958  640070970 2018-03-23 2018-03-23 18:52:43  Spring     End_of_Month
# 136269   54132871 2018-03-24 2018-03-24 19:09:01  Spring     End_of_Month
# 137724   54132871 2018-03-24 2018-03-24 19:09:01  Spring     End_of_Month
# 144926  640071047 2018-03-27 2018-03-27 15:19:14  Spring     End_of_Month
# 146806  640071058 2018-03-28 2018-03-28 10:08:11  Spring     End_of_Month
# 148762   54132954 2018-03-29 2018-03-29 17:10:41  Spring     End_of_Month
# 149466  640071106 2018-03-30 2018-03-30 16:10:12  Spring     End_of_Month
# 151004  640071123 2018-03-31 2018-03-31 11:03:19  Spring     End_of_Month
# 151430  740065460 2018-03-31 2018-03-31 12:03:46  Spring     End_of_Month
# 158887  640071209 2018-04-06 2018-04-07 10:14:59  Spring   Start_of_Month
# 160769   54133138 2018-04-07 2018-04-07 19:33:01  Spring   Start_of_Month
# 238243   54134537 2018-06-23 2018-06-23 19:43:50  Summer     End_of_Month
# 242262   50125533 2018-06-28 2018-06-28 17:22:34  Summer     End_of_Month
# 254555  640072879 2018-07-10 2018-07-10 16:27:19  Summer   Start_of_Month
# 319600  640074405 2018-08-18 2018-08-18 18:44:27  Summer  Middle_of_Month
# 319694  640074405 2018-08-18 2018-08-18 18:44:27  Summer  Middle_of_Month
# 324165  640074405 2018-08-18 2018-08-18 18:44:27  Summer  Middle_of_Month
# 324251  640074405 2018-08-18 2018-08-18 18:44:27  Summer  Middle_of_Month
# 342647  640074803 2018-08-28 2018-08-28 15:09:41  Summer     End_of_Month
# 345028  640074917 2018-08-30 2018-08-30 19:18:58  Summer     End_of_Month
# 345055  640074917 2018-08-30 2018-08-30 19:18:58  Summer     End_of_Month
# 348208  640074917 2018-08-30 2018-08-30 19:18:58  Summer     End_of_Month
# 348212  640074917 2018-08-30 2018-08-30 19:18:58  Summer     End_of_Month
# 349069  640074963 2018-08-31 2018-08-31 16:35:54  Summer     End_of_Month
# 349094  640074963 2018-08-31 2018-08-31 16:35:54  Summer     End_of_Month
# 349147  640074963 2018-08-31 2018-08-31 16:35:54  Summer     End_of_Month
# 352289  640074963 2018-08-31 2018-08-31 16:35:54  Summer     End_of_Month
# 352638  640074963 2018-08-31 2018-08-31 16:35:54  Summer     End_of_Month
# 352648  640074963 2018-08-31 2018-08-31 16:35:54  Summer     End_of_Month
# 368624   54136793 2018-09-05 2018-09-05 12:09:15  Summer   Start_of_Month
# 368628   54136793 2018-09-05 2018-09-05 12:09:15  Summer   Start_of_Month
# 369640   54136793 2018-09-05 2018-09-05 12:09:15  Summer   Start_of_Month
# 369643   54136793 2018-09-05 2018-09-05 12:09:15  Summer   Start_of_Month
# 386896  800151799 2018-09-11 2018-09-11 16:42:52  Summer  Middle_of_Month
# 387919  800151799 2018-09-11 2018-09-11 16:42:52  Summer  Middle_of_Month
# 421740  640075725 2018-09-25 2018-09-25 17:37:55  Autumn     End_of_Month
# 421741  640075725 2018-09-25 2018-09-25 17:37:55  Autumn     End_of_Month
# 441102   54137504 2018-09-30 2018-09-30 17:42:03  Autumn     End_of_Month
# 536110   54138712 2018-12-31 2018-12-31 14:07:12  Winter     End_of_Month
#
#                P_WEEK      COVID CONFINEMENT CURFEW         LOCATION  ...  \
# 34265        Mid_Week  Pre-Covid          NO     NO      Ksar Hellal  ...
# 65879        Week_End  Pre-Covid          NO     NO           Nabeul  ...
# 69132   Start_of_Week  Pre-Covid          NO     NO           Nabeul  ...
# 73001        Mid_Week  Pre-Covid          NO     NO           Nabeul  ...
# 73292        Mid_Week  Pre-Covid          NO     NO           Nabeul  ...
# 90228   Start_of_Week  Pre-Covid          NO     NO           Nabeul  ...
# 96664        Mid_Week  Pre-Covid          NO     NO           Nabeul  ...
# 96665        Mid_Week  Pre-Covid          NO     NO           Nabeul  ...
# 96763        Mid_Week  Pre-Covid          NO     NO           Nabeul  ...
# 96781        Mid_Week  Pre-Covid          NO     NO           Nabeul  ...
# 96782        Mid_Week  Pre-Covid          NO     NO           Nabeul  ...
# 96944        Mid_Week  Pre-Covid          NO     NO           Nabeul  ...
# 114883       Mid_Week  Pre-Covid          NO     NO           Nabeul  ...
# 119431       Week_end  Pre-Covid          NO     NO           Nabeul  ...
# 121665       Mid_Week  Pre-Covid          NO     NO           Nabeul  ...
# 124140       Mid_Week  Pre-Covid          NO     NO           Nabeul  ...
# 127023       Week_end  Pre-Covid          NO     NO           Nabeul  ...
# 128554  Start_of_Week  Pre-Covid          NO     NO           Nabeul  ...
# 128596  Start_of_Week  Pre-Covid          NO     NO           Nabeul  ...
# 129336  Start_of_Week  Pre-Covid          NO     NO           Nabeul  ...
# 133513       Mid_Week  Pre-Covid          NO     NO           Nabeul  ...
# 133958       Mid_Week  Pre-Covid          NO     NO           Nabeul  ...
# 136269       Week_End  Pre-Covid          NO     NO           Nabeul  ...
# 137724       Week_End  Pre-Covid          NO     NO           Nabeul  ...
# 144926  Start_of_Week  Pre-Covid          NO     NO           Nabeul  ...
# 146806       Mid_Week  Pre-Covid          NO     NO           Nabeul  ...
# 148762       Mid_Week  Pre-Covid          NO     NO           Nabeul  ...
# 149466       Mid_Week  Pre-Covid          NO     NO           Nabeul  ...
# 151004       Week_End  Pre-Covid          NO     NO           Nabeul  ...
# 151430       Week_End  Pre-Covid          NO     NO         Hammamet  ...
# 158887       Mid_Week  Pre-Covid          NO     NO           Nabeul  ...
# 160769       Week_End  Pre-Covid          NO     NO           Nabeul  ...
# 238243       Week_End  Pre-Covid          NO     NO           Nabeul  ...
# 242262       Mid_Week  Pre-Covid          NO     NO  Sasio Carrefour  ...
# 254555  Start_of_Week  Pre-Covid          NO     NO           Nabeul  ...
# 319600       Week_End  Pre-Covid          NO     NO           Nabeul  ...
# 319694       Week_End  Pre-Covid          NO     NO           Nabeul  ...
# 324165       Week_End  Pre-Covid          NO     NO           Nabeul  ...
# 324251       Week_End  Pre-Covid          NO     NO           Nabeul  ...
# 342647  Start_of_Week  Pre-Covid          NO     NO           Nabeul  ...
# 345028       Mid_Week  Pre-Covid          NO     NO           Nabeul  ...
# 345055       Mid_Week  Pre-Covid          NO     NO           Nabeul  ...
# 348208       Mid_Week  Pre-Covid          NO     NO           Nabeul  ...
# 348212       Mid_Week  Pre-Covid          NO     NO           Nabeul  ...
# 349069       Mid_Week  Pre-Covid          NO     NO           Nabeul  ...
# 349094       Mid_Week  Pre-Covid          NO     NO           Nabeul  ...
# 349147       Mid_Week  Pre-Covid          NO     NO           Nabeul  ...
# 352289       Mid_Week  Pre-Covid          NO     NO           Nabeul  ...
# 352638       Mid_Week  Pre-Covid          NO     NO           Nabeul  ...
# 352648       Mid_Week  Pre-Covid          NO     NO           Nabeul  ...
# 368624       Mid_Week  Pre-Covid          NO     NO           Nabeul  ...
# 368628       Mid_Week  Pre-Covid          NO     NO           Nabeul  ...
# 369640       Mid_Week  Pre-Covid          NO     NO           Nabeul  ...
# 369643       Mid_Week  Pre-Covid          NO     NO           Nabeul  ...
# 386896  Start_of_Week  Pre-Covid          NO     NO        Lafayette  ...
# 387919  Start_of_Week  Pre-Covid          NO     NO        Lafayette  ...
# 421740  Start_of_Week  Pre-Covid          NO     NO           Nabeul  ...
# 421741  Start_of_Week  Pre-Covid          NO     NO           Nabeul  ...
# 441102       Week_end  Pre-Covid          NO     NO           Nabeul  ...
# 536110  Start_of_Week  Pre-Covid          NO     NO           Nabeul  ...
#
#         ITEM_CODE          CC_LIBELLE              CC_LIBELLE_1 DESIGNATION  \
# 34265    NABEULÂ    26TN00F051316F18H  GRANDE TAILLE ( JASMIN )     TUNIQUE
# 65879   BIR MROUA      4PUPH23BNRS18H                      ISLD        PULL
# 69132    NABEULÂ     6PA00F031191F18H               SASIO FEMME    PANTALON
# 73001    NABEULÂ     4PA00H111264F18H               BLUE ISLAND    PANTALON
# 73292    NABEULÂ     4PA00H111264F18H               BLUE ISLAND    PANTALON
# 90228    NABEULÂ      4PA00H11960C18A               BLUE ISLAND    PANTALON
# 96664    NABEULÂ       27CHSBS1PRF18H                BLEU & SON   CHAUSSURE
# 96665    NABEULÂ       27CHSBS1PRF18H                BLEU & SON   CHAUSSURE
# 96763    NABEULÂ     6PA00F031181F18H               SASIO FEMME    PANTALON
# 96781    NABEULÂ     27BZ00BS1300417H                BLEU & SON     BLOUSON
# 96782    NABEULÂ     27BZ00BS1300417H                BLEU & SON     BLOUSON
# 96944    NABEULÂ     6PA00F031181F18H               SASIO FEMME    PANTALON
# 114883   NABEULÂ     6PA00F031173S18H               SASIO FEMME    PANTALON
# 119431   NABEULÂ     6PA00F031174S18H               SASIO FEMME    PANTALON
# 121665        NaN   4CHD00H10846BC18H               BLUE ISLAND     CHEMISE
# 124140   NABEULÂ    15CH00F051371F18H                     IPSOS     CHEMISE
# 127023   NABEULÂ     26RO00F08626F18H  GRANDE TAILLE ( JASMIN )        ROBE
# 128554   NABEULÂ     4PA00H111032F17H               BLUE ISLAND    PANTALON
# 128596   NABEULÂ    15CH00F051371F18H                     IPSOS     CHEMISE
# 129336   NABEULÂ     6PA00F031151S17E               SASIO FEMME    PANTALON
# 133513       BEJA      27CHSBS1PRF18H                BLEU & SON   CHAUSSURE
# 133958       BEJA      27CHSBS1PRF18H                BLEU & SON   CHAUSSURE
# 136269   NABEULÂ    4CHMLH10477AMO18H               BLUE ISLAND     CHEMISE
# 137724   NABEULÂ    4CHMLH10477AMO18H               BLUE ISLAND     CHEMISE
# 144926   NABEULÂ     6TN00F051436F18H               SASIO FEMME     TUNIQUE
# 146806   NABEULÂ     6PA00F031180S18H               SASIO FEMME    PANTALON
# 148762   NABEULÂ     6BL00F051423F18A               SASIO FEMME      BLOUSE
# 149466   NABEULÂ       15TN00ROS8218H               SASIO FEMME     TUNIQUE
# 151004     NABEUL        6SACMAC1918E               SASIO FEMME         SAC
# 151430   HAMMAMET    6PA00F031172S18H               SASIO FEMME    PANTALON
# 158887     NABEUL       6CHS371PRF18E               SASIO FEMME   CHAUSSURE
# 160769     NABEUL    6BL00F051407F18H               SASIO FEMME      BLOUSE
# 238243   NABEULÂ         6SD406CGA18E               SASIO FEMME     SANDALE
# 242262       KRAM  20TN00F051416CP17E                   CAPSULE     TUNIQUE
# 254555   NABEULÂ   20TN00F051372CP17E                   CAPSULE     TUNIQUE
# 319600   NABEULÂ   20CH00F051347CP17E                   CAPSULE     CHEMISE
# 319694   NABEULÂ    17PO00H171297F18E               ISLAND CLUB        POLO
# 324165   NABEULÂ    17PO00H171297F18E               ISLAND CLUB        POLO
# 324251   NABEULÂ   20CH00F051347CP17E                   CAPSULE     CHEMISE
# 342647   NABEULÂ     6PA00F031174S18H               SASIO FEMME    PANTALON
# 345028   NABEULÂ    4CHC01H10714DF18E               BLUE ISLAND     CHEMISE
# 345055   NABEULÂ    4CHC00H10711DC18E               BLUE ISLAND     CHEMISE
# 348208   NABEULÂ    4CHC00H10711DC18E               BLUE ISLAND     CHEMISE
# 348212   NABEULÂ    4CHC01H10714DF18E               BLUE ISLAND     CHEMISE
# 349069   NABEULÂ     6PA00F031076F18S               SASIO FEMME    PANTALON
# 349094   NABEULÂ        6MU152CICT18E               SASIO FEMME        MULE
# 349147   NABEULÂ     6TN00F051436F18H               SASIO FEMME     TUNIQUE
# 352289   NABEULÂ     6TN00F051436F18H               SASIO FEMME     TUNIQUE
# 352638   NABEULÂ        6MU152CICT18E               SASIO FEMME        MULE
# 352648   NABEULÂ     6PA00F031076F18S               SASIO FEMME    PANTALON
# 368624   NABEULÂ     6PA00F031173S18H               SASIO FEMME    PANTALON
# 368628   NABEULÂ     6PA00F031177S18H               SASIO FEMME    PANTALON
# 369640   NABEULÂ     6PA00F031177S18H               SASIO FEMME    PANTALON
# 369643   NABEULÂ     6PA00F031173S18H               SASIO FEMME    PANTALON
# 386896     NABEUL    6RO00F08666CP18E               SASIO FEMME        ROBE
# 387919     NABEUL    6RO00F08666CP18E               SASIO FEMME        ROBE
# 421740   NABEULÂ      4PA00H11960C18A               BLUE ISLAND    PANTALON
# 421741   NABEULÂ      4PA00H11960C18A               BLUE ISLAND    PANTALON
# 441102   NABEULÂ       4MU10925RID18E               BLUE ISLAND        MULE
# 536110   NABEULÂ         6PU570NRS19H               SASIO FEMME        PULL
#
#                       PVTTC  QTEFACT PUTTCNET MLR_REMISE GTR_LIBELLE  \
# 34265   MARINE/ROSE VIOLINE     89.9        1     62.930     30.0000
# 65879           PRUNE/BEIGE     89.9        1     53.940     40.0000
# 69132                 PRUNE     89.9        1     62.930     30.0000
# 73001                  KAKI     89.9        1     50.344     20.0000
# 73292                  KAKI     89.9        1     62.930     30.0000
# 90228          BLEU PETROLE     89.9        1     71.920     20.0000
# 96664                  NOIR     89.9        1     44.950     50.0000
# 96665                  NOIR     89.9        1     35.960     20.0000
# 96763                  NOIR     89.9        1     50.344     20.0000
# 96781                 PRUNE     89.9        1     44.950     50.0000
# 96782                 PRUNE     89.9        1     35.960     20.0000
# 96944                  NOIR     89.9        1     62.930     30.0000
# 114883          JEAN DELAVE     89.9        1     71.920     20.0000
# 119431          JEAN DELAVE     89.9        1     71.920     20.0000
# 121665                 BLEU     89.9        1     71.920     20.0000
# 124140                 NOIR     89.9        1     44.950     50.0000
# 127023            NOIR/ECRU     89.9        1     44.950     50.0000
# 128554           GRIS FONCE     89.9        1     44.950     50.0000
# 128596                 NOIR     89.9        1     44.950     50.0000
# 129336          JEAN DELAVE     89.9        1     71.920     20.0000
# 133513                CAMEL     89.9        1     26.970     70.0000
# 133958                CAMEL     89.9        1     21.576     20.0000
# 136269       MULTI-COULEURS     89.9        1     35.960     20.0000
# 137724       MULTI-COULEURS     89.9        1     44.950     50.0000
# 144926             MOUTARDE     89.9        1     71.920     20.0000
# 146806                 JEAN     89.9        1     71.920     20.0000
# 148762                 NOIR     89.9        1     35.960     60.0000
# 149466             CHOCOLAT     89.9        1     35.960     60.0000
# 151004                 NOIR     89.9        1     44.950     50.0000
# 151430          JEAN DELAVE     89.9        1     44.950     50.0000
# 158887            ROSE PALE     89.9        1     62.930     30.0000
# 160769          MARINE/VERT     89.9        1     26.970     70.0000
# 238243                ROUGE     89.9        1     69.900     22.2469
# 242262               MARINE     89.9        1     67.301     25.1383
# 254555                BLANC     89.9        1     19.900      0.0000
# 319600               SAUMON     89.9        1     35.960     60.0000
# 319694          BLANC/ROUGE     89.9        1     53.940     40.0000
# 324165          BLANC/ROUGE     89.9        1     43.152     20.0000
# 324251               SAUMON     89.9        1     28.768     20.0000
# 342647          JEAN DELAVE     89.9        1     53.940     40.0000
# 345028          BLANC/ROUGE     89.9        1     35.960     20.0000
# 345055        BLEU/MOUTARDE     89.9        1     43.152     20.0000
# 348208        BLEU/MOUTARDE     89.9        1     53.940     40.0000
# 348212          BLANC/ROUGE     89.9        1     44.950     50.0000
# 349069                BEIGE     89.9        1     44.950     50.0000
# 349094                BEIGE     89.9        1     62.930     30.0000
# 349147                 NOIR     89.9        1     35.960     60.0000
# 352289                 NOIR     89.9        1     28.768     20.0000
# 352638                BEIGE     89.9        1     50.344     20.0000
# 352648                BEIGE     89.9        1     35.960     20.0000
# 368624          JEAN DELAVE     89.9        1     43.152     20.0000
# 368628                 GRIS     89.9        1     28.768     20.0000
# 369640                 GRIS     89.9        1     35.960     60.0000
# 369643          JEAN DELAVE     89.9        1     53.940     40.0000
# 386896                 NOIR     89.9        1     43.152     20.0000
# 387919                 NOIR     89.9        1     53.940     40.0000
# 421740                CAMEL     89.9        1     53.940     40.0000
# 421741                CAMEL     89.9        1     37.758     30.0000
# 441102                 NOIR     89.9        1     26.970     70.0000
# 536110               MARINE     89.9        1        NaN         NaN
#
#        TOTAL_QUANTITY
# 34265               2
# 65879               1
# 69132               3
# 73001               8
# 73292               8
# 90228               3
# 96664              12
# 96665              12
# 96763              12
# 96781              12
# 96782              12
# 96944              12
# 114883              1
# 119431              2
# 121665              1
# 124140              1
# 127023              3
# 128554              2
# 128596              1
# 129336              1
# 133513             10
# 133958             10
# 136269              4
# 137724              4
# 144926              3
# 146806              3
# 148762              1
# 149466              1
# 151004              2
# 151430              2
# 158887              1
# 160769              3
# 238243              1
# 242262              2
# 254555              2
# 319600             14
# 319694             14
# 324165             14
# 324251             14
# 342647              1
# 345028              8
# 345055              8
# 348208              8
# 348212              8
# 349069             12
# 349094             12
# 349147             12
# 352289             12
# 352638             12
# 352648             12
# 368624              6
# 368628              6
# 369640              6
# 369643              6
# 386896              6
# 387919              6
# 421740              6
# 421741              6
# 441102              1
# 536110              2
#
# [60 rows x 31 columns]

# %%
hour=df['TIME-ADD'].dt.hour
hour
# Out:
# 0         12
# 1         16
# 2         17
# 3         14
# 4         16
#           ..
# 536843    13
# 536844    13
# 536845    14
# 536846    11
# 536847    11
# Name: TIME-ADD, Length: 536848, dtype: int64

# %%
# Create the dictionary for Hour 

H = {0:'Early_morning', 1:'Early_morning', 2:'Early_morning', 3:'Early_morning',4:'Early_morning',5:'Early_morning',6:'Early_morning',7:'Early_morning',8:'Early_morning',9:'Late_morning',10:'Late_morning',11:'Late_morning',12:'Early_afternoon',13:'Early_afternoon',14:'Early_afternoon',15:'Late_afternoon',16:'Late_afternoon',17:'Late_afternoon',18:'Evening',19:'Evening',20:'Evening',21:'Night',22:'Night',23:'Night'}
# Use the dictionary to map the 'Hour'
df['HOUR'] = hour.map(H)
#display the first 5 lines
df
# Out:
# C:\Users\sofi\Anacondaa\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
#         ID_ORDER   DATE-ADD            TIME-ADD  SEASON         P_MONTH  \
# 0       66032518 2018-01-01 2018-01-01 12:06:50  Winter  Start_of_Month
# 1       80143573 2018-01-01 2018-01-01 16:03:37  Winter  Start_of_Month
# 2       80143576 2018-01-01 2018-01-01 17:38:26  Winter  Start_of_Month
# 3       80143572 2018-01-01 2018-01-01 14:52:08  Winter  Start_of_Month
# 4       80143574 2018-01-01 2018-01-01 16:56:04  Winter  Start_of_Month
# ...          ...        ...                 ...     ...             ...
# 536843  24168599 2018-12-31 2018-12-31 13:40:18  Winter    End_of_Month
# 536844  24168598 2018-12-31 2018-12-31 13:39:30  Winter    End_of_Month
# 536845  24168602 2018-12-31 2018-12-31 14:40:15  Winter    End_of_Month
# 536846  14142423 2018-12-31 2018-12-31 11:04:33  Winter    End_of_Month
# 536847  14142426 2018-12-31 2018-12-31 11:16:19  Winter    End_of_Month
#
#                P_WEEK      COVID CONFINEMENT CURFEW            LOCATION  ...  \
# 0       Start_of_Week  Pre-Covid          NO     NO              Mehdia  ...
# 1       Start_of_Week  Pre-Covid          NO     NO           Lafayette  ...
# 2       Start_of_Week  Pre-Covid          NO     NO           Lafayette  ...
# 3       Start_of_Week  Pre-Covid          NO     NO           Lafayette  ...
# 4       Start_of_Week  Pre-Covid          NO     NO           Lafayette  ...
# ...               ...        ...         ...    ...                 ...  ...
# 536843  Start_of_Week  Pre-Covid          NO     NO             Bizerte  ...
# 536844  Start_of_Week  Pre-Covid          NO     NO             Bizerte  ...
# 536845  Start_of_Week  Pre-Covid          NO     NO             Bizerte  ...
# 536846  Start_of_Week  Pre-Covid          NO     NO  Blue Island Zephyr  ...
# 536847  Start_of_Week  Pre-Covid          NO     NO  Blue Island Zephyr  ...
#
#            CC_LIBELLE CC_LIBELLE_1          DESIGNATION     PVTTC QTEFACT  \
# 0         SASIO FEMME       BLOUSE                 ROUX      79.9      -1
# 1         BLUE ISLAND         PULL                 BLEU      79.9       1
# 2         SASIO FEMME     CARDIGAN     MARINE/ROSE PALE      84.9       1
# 3       REQUEST FEMME       BLOUSE  MARINE/ROSE VIOLINE      49.9       1
# 4         SASIO FEMME  SWEAT SHIRT           ROSE CLAIR      59.9       1
# ...               ...          ...                  ...       ...     ...
# 536843    ISLAND CLUB      CHEMISE         BEIGE/MARRON  109.0000       1
# 536844    ISLAND CLUB     PANTALON               MARRON  129.0000       1
# 536845    BLUE ISLAND         PULL            GRIS PALE   89.9000       1
# 536846     BLEU & SON     PANTALON                CAMEL   59.9000      -1
# 536847    BLUE ISLAND     PANTALON                BEIGE  109.0000      -1
#
#         PUTTCNET MLR_REMISE GTR_LIBELLE TOTAL_QUANTITY             HOUR
# 0         -39.95    50.0000         NaN              4  Early_afternoon
# 1            NaN        NaN         NaN              1   Late_afternoon
# 2            NaN        NaN         NaN              2   Late_afternoon
# 3            NaN        NaN         NaN              1  Early_afternoon
# 4            NaN        NaN         NaN              1   Late_afternoon
# ...          ...        ...         ...            ...              ...
# 536843       NaN        NaN         NaN              2  Early_afternoon
# 536844       NaN        NaN         NaN              2  Early_afternoon
# 536845       NaN        NaN         NaN              2  Early_afternoon
# 536846     -59.8     0.1669         NaN              5     Late_morning
# 536847     -98.9     9.2661         NaN              2     Late_morning
#
# [536848 rows x 32 columns]

# %%
df = df[['ID_ORDER', 'DATE-ADD','TIME-ADD','HOUR','SEASON','P_MONTH','P_WEEK','COVID','CONFINEMENT','CURFEW','LOCATION','ID_CUSTOMER','LAST_NAME','FIRST_NAME','YX_LIBELLE','BIRTH_YEAR','AGE','TELEX','EMAIL','ADRESS','POSTAL_CODE','CITY','ITEM_CODE','CC_LIBELLE','CC_LIBELLE_1','DESIGNATION','PVTTC','QTEFACT','PUTTCNET','MLR_REMISE','GTR_LIBELLE','TOTAL_QUANTITY']]
df
# Out:
#         ID_ORDER   DATE-ADD            TIME-ADD             HOUR  SEASON  \
# 0       66032518 2018-01-01 2018-01-01 12:06:50  Early_afternoon  Winter
# 1       80143573 2018-01-01 2018-01-01 16:03:37   Late_afternoon  Winter
# 2       80143576 2018-01-01 2018-01-01 17:38:26   Late_afternoon  Winter
# 3       80143572 2018-01-01 2018-01-01 14:52:08  Early_afternoon  Winter
# 4       80143574 2018-01-01 2018-01-01 16:56:04   Late_afternoon  Winter
# ...          ...        ...                 ...              ...     ...
# 536843  24168599 2018-12-31 2018-12-31 13:40:18  Early_afternoon  Winter
# 536844  24168598 2018-12-31 2018-12-31 13:39:30  Early_afternoon  Winter
# 536845  24168602 2018-12-31 2018-12-31 14:40:15  Early_afternoon  Winter
# 536846  14142423 2018-12-31 2018-12-31 11:04:33     Late_morning  Winter
# 536847  14142426 2018-12-31 2018-12-31 11:16:19     Late_morning  Winter
#
#                P_MONTH         P_WEEK      COVID CONFINEMENT CURFEW  ...  \
# 0       Start_of_Month  Start_of_Week  Pre-Covid          NO     NO  ...
# 1       Start_of_Month  Start_of_Week  Pre-Covid          NO     NO  ...
# 2       Start_of_Month  Start_of_Week  Pre-Covid          NO     NO  ...
# 3       Start_of_Month  Start_of_Week  Pre-Covid          NO     NO  ...
# 4       Start_of_Month  Start_of_Week  Pre-Covid          NO     NO  ...
# ...                ...            ...        ...         ...    ...  ...
# 536843    End_of_Month  Start_of_Week  Pre-Covid          NO     NO  ...
# 536844    End_of_Month  Start_of_Week  Pre-Covid          NO     NO  ...
# 536845    End_of_Month  Start_of_Week  Pre-Covid          NO     NO  ...
# 536846    End_of_Month  Start_of_Week  Pre-Covid          NO     NO  ...
# 536847    End_of_Month  Start_of_Week  Pre-Covid          NO     NO  ...
#
#                  ITEM_CODE     CC_LIBELLE CC_LIBELLE_1          DESIGNATION  \
# 0         6BL00F051401F18H    SASIO FEMME       BLOUSE                 ROUX
# 1            4PUPH45NRS18H    BLUE ISLAND         PULL                 BLEU
# 2              6CR04NRS18H    SASIO FEMME     CARDIGAN     MARINE/ROSE PALE
# 3         22BL00FR0501518H  REQUEST FEMME       BLOUSE  MARINE/ROSE VIOLINE
# 4         6SW00F071556F18H    SASIO FEMME  SWEAT SHIRT           ROSE CLAIR
# ...                    ...            ...          ...                  ...
# 536843  17CHC00H10830DC19H    ISLAND CLUB      CHEMISE         BEIGE/MARRON
# 536844   17PA00H111360C19H    ISLAND CLUB     PANTALON               MARRON
# 536845         4PU18CND18H    BLUE ISLAND         PULL            GRIS PALE
# 536846    27PA00BS1105219H     BLEU & SON     PANTALON                CAMEL
# 536847    4PA00H111351F19H    BLUE ISLAND     PANTALON                BEIGE
#
#            PVTTC QTEFACT  PUTTCNET MLR_REMISE GTR_LIBELLE TOTAL_QUANTITY
# 0           79.9      -1    -39.95    50.0000         NaN              4
# 1           79.9       1       NaN        NaN         NaN              1
# 2           84.9       1       NaN        NaN         NaN              2
# 3           49.9       1       NaN        NaN         NaN              1
# 4           59.9       1       NaN        NaN         NaN              1
# ...          ...     ...       ...        ...         ...            ...
# 536843  109.0000       1       NaN        NaN         NaN              2
# 536844  129.0000       1       NaN        NaN         NaN              2
# 536845   89.9000       1       NaN        NaN         NaN              2
# 536846   59.9000      -1     -59.8     0.1669         NaN              5
# 536847  109.0000      -1     -98.9     9.2661         NaN              2
#
# [536848 rows x 32 columns]

# %%
df['TIME-ADD'] = pd.Series([val.time() for val in df['TIME-ADD']])
df
# Out:
#         ID_ORDER   DATE-ADD  TIME-ADD             HOUR  SEASON  \
# 0       66032518 2018-01-01  12:06:50  Early_afternoon  Winter
# 1       80143573 2018-01-01  16:03:37   Late_afternoon  Winter
# 2       80143576 2018-01-01  17:38:26   Late_afternoon  Winter
# 3       80143572 2018-01-01  14:52:08  Early_afternoon  Winter
# 4       80143574 2018-01-01  16:56:04   Late_afternoon  Winter
# ...          ...        ...       ...              ...     ...
# 536843  24168599 2018-12-31  13:40:18  Early_afternoon  Winter
# 536844  24168598 2018-12-31  13:39:30  Early_afternoon  Winter
# 536845  24168602 2018-12-31  14:40:15  Early_afternoon  Winter
# 536846  14142423 2018-12-31  11:04:33     Late_morning  Winter
# 536847  14142426 2018-12-31  11:16:19     Late_morning  Winter
#
#                P_MONTH         P_WEEK      COVID CONFINEMENT CURFEW  ...  \
# 0       Start_of_Month  Start_of_Week  Pre-Covid          NO     NO  ...
# 1       Start_of_Month  Start_of_Week  Pre-Covid          NO     NO  ...
# 2       Start_of_Month  Start_of_Week  Pre-Covid          NO     NO  ...
# 3       Start_of_Month  Start_of_Week  Pre-Covid          NO     NO  ...
# 4       Start_of_Month  Start_of_Week  Pre-Covid          NO     NO  ...
# ...                ...            ...        ...         ...    ...  ...
# 536843    End_of_Month  Start_of_Week  Pre-Covid          NO     NO  ...
# 536844    End_of_Month  Start_of_Week  Pre-Covid          NO     NO  ...
# 536845    End_of_Month  Start_of_Week  Pre-Covid          NO     NO  ...
# 536846    End_of_Month  Start_of_Week  Pre-Covid          NO     NO  ...
# 536847    End_of_Month  Start_of_Week  Pre-Covid          NO     NO  ...
#
#                  ITEM_CODE     CC_LIBELLE CC_LIBELLE_1          DESIGNATION  \
# 0         6BL00F051401F18H    SASIO FEMME       BLOUSE                 ROUX
# 1            4PUPH45NRS18H    BLUE ISLAND         PULL                 BLEU
# 2              6CR04NRS18H    SASIO FEMME     CARDIGAN     MARINE/ROSE PALE
# 3         22BL00FR0501518H  REQUEST FEMME       BLOUSE  MARINE/ROSE VIOLINE
# 4         6SW00F071556F18H    SASIO FEMME  SWEAT SHIRT           ROSE CLAIR
# ...                    ...            ...          ...                  ...
# 536843  17CHC00H10830DC19H    ISLAND CLUB      CHEMISE         BEIGE/MARRON
# 536844   17PA00H111360C19H    ISLAND CLUB     PANTALON               MARRON
# 536845         4PU18CND18H    BLUE ISLAND         PULL            GRIS PALE
# 536846    27PA00BS1105219H     BLEU & SON     PANTALON                CAMEL
# 536847    4PA00H111351F19H    BLUE ISLAND     PANTALON                BEIGE
#
#            PVTTC QTEFACT  PUTTCNET MLR_REMISE GTR_LIBELLE TOTAL_QUANTITY
# 0           79.9      -1    -39.95    50.0000         NaN              4
# 1           79.9       1       NaN        NaN         NaN              1
# 2           84.9       1       NaN        NaN         NaN              2
# 3           49.9       1       NaN        NaN         NaN              1
# 4           59.9       1       NaN        NaN         NaN              1
# ...          ...     ...       ...        ...         ...            ...
# 536843  109.0000       1       NaN        NaN         NaN              2
# 536844  129.0000       1       NaN        NaN         NaN              2
# 536845   89.9000       1       NaN        NaN         NaN              2
# 536846   59.9000      -1     -59.8     0.1669         NaN              5
# 536847  109.0000      -1     -98.9     9.2661         NaN              2
#
# [536848 rows x 32 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 536848 entries, 0 to 536847
# Data columns (total 32 columns):
# ID_ORDER          536848 non-null int32
# DATE-ADD          536848 non-null datetime64[ns]
# TIME-ADD          536848 non-null object
# HOUR              536848 non-null object
# SEASON            536848 non-null object
# P_MONTH           536848 non-null object
# P_WEEK            536848 non-null object
# COVID             536848 non-null object
# CONFINEMENT       536848 non-null object
# CURFEW            536848 non-null object
# LOCATION          536848 non-null object
# ID_CUSTOMER       536848 non-null object
# LAST_NAME         536848 non-null object
# FIRST_NAME        271624 non-null object
# YX_LIBELLE        426416 non-null object
# BIRTH_YEAR        536840 non-null datetime64[ns]
# AGE               536840 non-null float64
# TELEX             267784 non-null object
# EMAIL             134450 non-null object
# ADRESS            177862 non-null object
# POSTAL_CODE       439634 non-null object
# CITY              439129 non-null object
# ITEM_CODE         536847 non-null object
# CC_LIBELLE        536387 non-null object
# CC_LIBELLE_1      536387 non-null object
# DESIGNATION       536387 non-null object
# PVTTC             536848 non-null object
# QTEFACT           536848 non-null object
# PUTTCNET          445275 non-null object
# MLR_REMISE        445214 non-null float64
# GTR_LIBELLE       439960 non-null object
# TOTAL_QUANTITY    536848 non-null int64
# dtypes: datetime64[ns](2), float64(2), int32(1), int64(1), object(26)
# memory usage: 129.0+ MB

# %%
new_row2070 = {'POST_CODE':'2070', 'Delegation':'LA MARSA', 'poverty rate':2.2, 'zone':'urbaine','orientation':'nord-est'}
df2 = df2.append(new_row2070, ignore_index=True)

# %%
df['POSTAL_CODE']=df['POSTAL_CODE'].apply(str)
df2['POST_CODE']=df2['POST_CODE'].apply(str)
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 970 entries, 0 to 969
# Data columns (total 5 columns):
# POST_CODE       970 non-null object
# Delegation      970 non-null object
# poverty rate    970 non-null float64
# zone            970 non-null object
# orientation     970 non-null object
# dtypes: float64(1), object(4)
# memory usage: 38.0+ KB

# %%
df2
# Out:
#     POST_CODE    Delegation  poverty rate     zone orientation class
# 0        2072       SEJOUMI          11.5  urbaine    nord-est    C+
# 1        1007       SEJOUMI          11.5  urbaine    nord-est    C+
# 2        2023   JEBEL JLOUD           9.5  urbaine    nord-est    C+
# 3        1046   JEBEL JLOUD           9.5  urbaine    nord-est    C+
# 4        1095  SIDI HASSINE           9.4  urbaine    nord-est    C+
# ..        ...           ...           ...      ...         ...   ...
# 965      4273   KEBILI NORD          12.3  urbaine   sud-ouest    C+
# 966      4237   KEBILI NORD          12.3  urbaine   sud-ouest    C+
# 967      4232   KEBILI NORD          12.3  urbaine   sud-ouest    C+
# 968      4235   KEBILI NORD          12.3  urbaine   sud-ouest    C+
# 969      2070      LA MARSA           2.2  urbaine    nord-est     B
#
# [970 rows x 6 columns]

# %%
def get_region(code, train):
  try:
    if str(code) in str(train['POST_CODE'].unique()):
        return str(train[train['POST_CODE']== str(code)]['orientation'].values[0])
  except Exception :
    print (str(code))

# %%
df['region'] = df.apply(lambda x: get_region(x.POSTAL_CODE, df2), axis=1)
# Out:
# 900
# 710
# 710
#
#
#
#
# 800
# 800
# 800
# 800
# 800
# 800
# 24
# 24
# 803
# 803
# 700
# 700
# 900
# 900
# 142
# 142
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 801
# 801

# %%
df['region'].value_counts()
# Out:
# nord-est        365108
# centre-est       36180
# nord-ouest       11337
# centre-ouest     10319
# sud-est           5950
# sud-ouest         5616
# Name: region, dtype: int64

# %%
df['POSTAL_CODE'][df['region'].isnull()]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anacondaa\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'region'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-68-ac46a33f506d> in <module>
# ----> 1 df['POSTAL_CODE'][df['region'].isnull()]
#
# ~\Anacondaa\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2978             if self.columns.nlevels > 1:
#    2979                 return self._getitem_multilevel(key)
# -> 2980             indexer = self.columns.get_loc(key)
#    2981             if is_integer(indexer):
#    2982                 indexer = [indexer]
#
# ~\Anacondaa\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
# -> 2899                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2900         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2901         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'region'

# %%
df2[df2['POST_CODE']=='2037']
# Out:
#     POST_CODE    Delegation  poverty rate     zone orientation
# 109      2037  ARIANA Ville           1.3  urbaine    nord-est

# %%
df2
# Out:
#     POST_CODE    Delegation  poverty rate     zone orientation
# 0        2072       SEJOUMI          11.5  urbaine    nord-est
# 1        1007       SEJOUMI          11.5  urbaine    nord-est
# 2        2023   JEBEL JLOUD           9.5  urbaine    nord-est
# 3        1046   JEBEL JLOUD           9.5  urbaine    nord-est
# 4        1095  SIDI HASSINE           9.4  urbaine    nord-est
# ..        ...           ...           ...      ...         ...
# 965      4273   KEBILI NORD          12.3  urbaine   sud-ouest
# 966      4237   KEBILI NORD          12.3  urbaine   sud-ouest
# 967      4232   KEBILI NORD          12.3  urbaine   sud-ouest
# 968      4235   KEBILI NORD          12.3  urbaine   sud-ouest
# 969      2070      LA MARSA           2.2  urbaine    nord-est
#
# [970 rows x 5 columns]

# %%
df.iloc[3575 ,:]
# Out:
# ID_ORDER                         40037874
# DATE-ADD              2018-01-05 00:00:00
# TIME-ADD                         17:47:14
# HOUR                       Late_afternoon
# SEASON                             Winter
# P_MONTH                    Start_of_Month
# P_WEEK                           Mid_Week
# COVID                           Pre-Covid
# CONFINEMENT                            NO
# CURFEW                                 NO
# LOCATION                           Ennasr
# ID_CUSTOMER                      S2021453
# LAST_NAME                          JAOUNI
# FIRST_NAME                         Wahida
# YX_LIBELLE                            NaN
# BIRTH_YEAR            1976-01-01 00:00:00
# AGE                                    42
# TELEX                            97532141
# EMAIL             wjaouini.lawer@yahoo.fr
# ADRESS                Rsdbarr B31 Nasser2
# POSTAL_CODE                          2038
# CITY                               ARIANA
# ITEM_CODE                22TN00FR0501418H
# CC_LIBELLE                  REQUEST FEMME
# CC_LIBELLE_1                      TUNIQUE
# DESIGNATION                    NOIR/ROUGE
# PVTTC                                59.9
# QTEFACT                                 1
# PUTTCNET                              NaN
# MLR_REMISE                            NaN
# GTR_LIBELLE                           NaN
# TOTAL_QUANTITY                          2
# region                               None
# Name: 3575, dtype: object

# %%
df.iloc[536836 ,:]
# Out:
# ID_ORDER                     24168610
# DATE-ADD          2018-12-31 00:00:00
# TIME-ADD                     15:05:22
# HOUR                   Late_afternoon
# SEASON                         Winter
# P_MONTH                  End_of_Month
# P_WEEK                  Start_of_Week
# COVID                       Pre-Covid
# CONFINEMENT                        NO
# CURFEW                             NO
# LOCATION                      Bizerte
# ID_CUSTOMER                 BC0240558
# LAST_NAME                    ALLOUCHE
# FIRST_NAME                     Mohsen
# YX_LIBELLE                 PARTENAIRE
# BIRTH_YEAR        1900-01-01 00:00:00
# AGE                           64.6614
# TELEX                        23568164
# EMAIL                             NaN
# ADRESS                        Bizerte
# POSTAL_CODE                       nan
# CITY                              NaN
# ITEM_CODE                4DDL046GS19H
# CC_LIBELLE                BLUE ISLAND
# CC_LIBELLE_1                 DOUDOUNE
# DESIGNATION                      NOIR
# PVTTC                        229.0000
# QTEFACT                             1
# PUTTCNET                          NaN
# MLR_REMISE                        NaN
# GTR_LIBELLE                       NaN
# TOTAL_QUANTITY                      2
# region                           None
# Name: 536836, dtype: object

# %%
def get_area(code, train):
  try:
    if str(code) in str(train['POST_CODE'].unique()):
        return str(train[train['POST_CODE']== str(code)]['zone'].values[0])
  except Exception :
    print (str(code))

# %%
df['area'] = df.apply(lambda x: get_area(x.POSTAL_CODE, df2), axis=1)
# Out:
# 900
# 710
# 710
#
#
#
#
# 800
# 800
# 800
# 800
# 800
# 800
# 24
# 24
# 803
# 803
# 700
# 700
# 900
# 900
# 142
# 142
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 801
# 801

# %%
df['area'].value_counts()
# Out:
# urbaine    434426
# rurale         84
# Name: area, dtype: int64

# %%
df[df['POSTAL_CODE']=='2070']
# Out:
#          ID_ORDER   DATE-ADD  TIME-ADD            HOUR  SEASON  \
# 427      69025950 2018-01-02  18:31:14         Evening  Winter
# 428      69025950 2018-01-02  18:31:14         Evening  Winter
# 429      69025947 2018-01-02  16:59:39  Late_afternoon  Winter
# 430      69025950 2018-01-02  18:31:14         Evening  Winter
# 434      69025950 2018-01-02  18:31:14         Evening  Winter
# ...           ...        ...       ...             ...     ...
# 534378   37020133 2018-12-31  17:35:26  Late_afternoon  Winter
# 535855   37020129 2018-12-31  16:32:50  Late_afternoon  Winter
# 535874   37020135 2018-12-31  17:42:02  Late_afternoon  Winter
# 535890   37020133 2018-12-31  17:35:26  Late_afternoon  Winter
# 536041  420004136 2018-12-31  10:46:31    Late_morning  Winter
#
#                P_MONTH         P_WEEK      COVID CONFINEMENT CURFEW  ...  \
# 427     Start_of_Month  Start_of_Week  Pre-Covid          NO     NO  ...
# 428     Start_of_Month  Start_of_Week  Pre-Covid          NO     NO  ...
# 429     Start_of_Month  Start_of_Week  Pre-Covid          NO     NO  ...
# 430     Start_of_Month  Start_of_Week  Pre-Covid          NO     NO  ...
# 434     Start_of_Month  Start_of_Week  Pre-Covid          NO     NO  ...
# ...                ...            ...        ...         ...    ...  ...
# 534378    End_of_Month  Start_of_Week  Pre-Covid          NO     NO  ...
# 535855    End_of_Month  Start_of_Week  Pre-Covid          NO     NO  ...
# 535874    End_of_Month  Start_of_Week  Pre-Covid          NO     NO  ...
# 535890    End_of_Month  Start_of_Week  Pre-Covid          NO     NO  ...
# 536041    End_of_Month  Start_of_Week  Pre-Covid          NO     NO  ...
#
#        CC_LIBELLE_1      DESIGNATION     PVTTC QTEFACT PUTTCNET MLR_REMISE  \
# 427             TOP       GRIS CLAIR      49.9       1   11.456    77.0416
# 428             TOP       GRIS CLAIR      49.9       1    3.767    67.1141
# 429           VESTE             KAKI     169.9       1    84.95    50.0000
# 430            PULL  MOUTARDE/MARINE      49.9       1        0   100.0000
# 434        PANTALON      JEAN DELAVE      79.9       1   18.344    77.0416
# ...             ...              ...       ...     ...      ...        ...
# 534378          TOP  NOIR/GRIS CLAIR   49.9000       1        0   100.0000
# 535855    CHAUSSURE            CAMEL  169.0000       1      NaN        NaN
# 535874     DOUDOUNE         BORDEAUX  249.0000       1      NaN        NaN
# 535890         PULL             BRUN   59.9000       1      NaN        NaN
# 536041       PONCHO         BORDEAUX   69.9000       1      NaN        NaN
#
#                      GTR_LIBELLE TOTAL_QUANTITY    region     area
# 427                    BON ACHAT              5  nord-est  urbaine
# 428                   FidÃ©litÃ©              5  nord-est  urbaine
# 429     2 eme 50 et le 3 eme 100              2  nord-est  urbaine
# 430     2 eme 50 et le 3 eme 100              5  nord-est  urbaine
# 434                    BON ACHAT              5  nord-est  urbaine
# ...                          ...            ...       ...      ...
# 534378              Vente flash               2  nord-est  urbaine
# 535855                       NaN              2  nord-est  urbaine
# 535874                       NaN              2  nord-est  urbaine
# 535890                       NaN              2  nord-est  urbaine
# 536041                       NaN              2  nord-est  urbaine
#
# [1803 rows x 34 columns]

# %%
df = df.rename(columns={'region': 'REGION'})
df = df.rename(columns={'area': 'AREA'})

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 970 entries, 0 to 969
# Data columns (total 5 columns):
# POST_CODE       970 non-null object
# Delegation      970 non-null object
# poverty rate    970 non-null float64
# zone            970 non-null object
# orientation     970 non-null object
# dtypes: float64(1), object(4)
# memory usage: 38.0+ KB

# %%
cut_class = ['A', 'B', 'C+','C-', 'D', 'E']
cut_bins =[0, 2, 8, 18, 26, 42, 55]
df2['class'] = pd.cut(df2['poverty rate'], bins=cut_bins, labels = cut_class)
df2
# Out:
#     POST_CODE    Delegation  poverty rate     zone orientation class
# 0        2072       SEJOUMI          11.5  urbaine    nord-est    C+
# 1        1007       SEJOUMI          11.5  urbaine    nord-est    C+
# 2        2023   JEBEL JLOUD           9.5  urbaine    nord-est    C+
# 3        1046   JEBEL JLOUD           9.5  urbaine    nord-est    C+
# 4        1095  SIDI HASSINE           9.4  urbaine    nord-est    C+
# ..        ...           ...           ...      ...         ...   ...
# 965      4273   KEBILI NORD          12.3  urbaine   sud-ouest    C+
# 966      4237   KEBILI NORD          12.3  urbaine   sud-ouest    C+
# 967      4232   KEBILI NORD          12.3  urbaine   sud-ouest    C+
# 968      4235   KEBILI NORD          12.3  urbaine   sud-ouest    C+
# 969      2070      LA MARSA           2.2  urbaine    nord-est     B
#
# [970 rows x 6 columns]

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 970 entries, 0 to 969
# Data columns (total 6 columns):
# POST_CODE       970 non-null object
# Delegation      970 non-null object
# poverty rate    970 non-null float64
# zone            970 non-null object
# orientation     970 non-null object
# class           970 non-null category
# dtypes: category(1), float64(1), object(4)
# memory usage: 39.2+ KB

# %%
def get_class(code, train):
  try:
    if str(code) in str(train['POST_CODE'].unique()):
      return str(train[train['POST_CODE']== str(code)]['class'].values[0])
  except Exception :
    print (str(code))

# %%
df['CLASS'] = df.apply(lambda x: get_class(x.POSTAL_CODE, df2), axis=1)
# Out:
# 900
# 710
# 710
#
#
#
#
# 800
# 800
# 800
# 800
# 800
# 800
# 24
# 24
# 803
# 803
# 700
# 700
# 900
# 900
# 142
# 142
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 801
# 801

# %%
df
# Out:
#         ID_ORDER   DATE-ADD  TIME-ADD             HOUR  SEASON  \
# 0       66032518 2018-01-01  12:06:50  Early_afternoon  Winter
# 1       80143573 2018-01-01  16:03:37   Late_afternoon  Winter
# 2       80143576 2018-01-01  17:38:26   Late_afternoon  Winter
# 3       80143572 2018-01-01  14:52:08  Early_afternoon  Winter
# 4       80143574 2018-01-01  16:56:04   Late_afternoon  Winter
# ...          ...        ...       ...              ...     ...
# 536843  24168599 2018-12-31  13:40:18  Early_afternoon  Winter
# 536844  24168598 2018-12-31  13:39:30  Early_afternoon  Winter
# 536845  24168602 2018-12-31  14:40:15  Early_afternoon  Winter
# 536846  14142423 2018-12-31  11:04:33     Late_morning  Winter
# 536847  14142426 2018-12-31  11:16:19     Late_morning  Winter
#
#                P_MONTH         P_WEEK      COVID CONFINEMENT CURFEW  ...  \
# 0       Start_of_Month  Start_of_Week  Pre-Covid          NO     NO  ...
# 1       Start_of_Month  Start_of_Week  Pre-Covid          NO     NO  ...
# 2       Start_of_Month  Start_of_Week  Pre-Covid          NO     NO  ...
# 3       Start_of_Month  Start_of_Week  Pre-Covid          NO     NO  ...
# 4       Start_of_Month  Start_of_Week  Pre-Covid          NO     NO  ...
# ...                ...            ...        ...         ...    ...  ...
# 536843    End_of_Month  Start_of_Week  Pre-Covid          NO     NO  ...
# 536844    End_of_Month  Start_of_Week  Pre-Covid          NO     NO  ...
# 536845    End_of_Month  Start_of_Week  Pre-Covid          NO     NO  ...
# 536846    End_of_Month  Start_of_Week  Pre-Covid          NO     NO  ...
# 536847    End_of_Month  Start_of_Week  Pre-Covid          NO     NO  ...
#
#                 DESIGNATION     PVTTC QTEFACT PUTTCNET MLR_REMISE GTR_LIBELLE  \
# 0                      ROUX      79.9      -1   -39.95    50.0000         NaN
# 1                      BLEU      79.9       1      NaN        NaN         NaN
# 2          MARINE/ROSE PALE      84.9       1      NaN        NaN         NaN
# 3       MARINE/ROSE VIOLINE      49.9       1      NaN        NaN         NaN
# 4                ROSE CLAIR      59.9       1      NaN        NaN         NaN
# ...                     ...       ...     ...      ...        ...         ...
# 536843         BEIGE/MARRON  109.0000       1      NaN        NaN         NaN
# 536844               MARRON  129.0000       1      NaN        NaN         NaN
# 536845            GRIS PALE   89.9000       1      NaN        NaN         NaN
# 536846                CAMEL   59.9000      -1    -59.8     0.1669         NaN
# 536847                BEIGE  109.0000      -1    -98.9     9.2661         NaN
#
#         TOTAL_QUANTITY    REGION     AREA CLASS
# 0                    4  nord-est  urbaine     B
# 1                    1  nord-est  urbaine     B
# 2                    2  nord-est  urbaine     B
# 3                    1  nord-est  urbaine     B
# 4                    1  nord-est  urbaine     B
# ...                ...       ...      ...   ...
# 536843               2  nord-est  urbaine    C+
# 536844               2  nord-est  urbaine    C+
# 536845               2      None     None  None
# 536846               5      None     None  None
# 536847               2  nord-est  urbaine     B
#
# [536848 rows x 35 columns]

# %%
df.isnull().sum()
# Out:
# ID_ORDER               0
# DATE-ADD               0
# TIME-ADD               0
# HOUR                   0
# SEASON                 0
# P_MONTH                0
# P_WEEK                 0
# COVID                  0
# CONFINEMENT            0
# CURFEW                 0
# LOCATION               0
# ID_CUSTOMER            0
# LAST_NAME              0
# FIRST_NAME        265224
# YX_LIBELLE        110432
# BIRTH_YEAR             8
# AGE                    8
# TELEX             269064
# EMAIL             402398
# ADRESS            358986
# POSTAL_CODE            0
# CITY               97719
# ITEM_CODE              1
# CC_LIBELLE           461
# CC_LIBELLE_1         461
# DESIGNATION          461
# PVTTC                  0
# QTEFACT                0
# PUTTCNET           91573
# MLR_REMISE         91634
# GTR_LIBELLE        96888
# TOTAL_QUANTITY         0
# REGION            102338
# AREA              102338
# CLASS             102338
# dtype: int64
